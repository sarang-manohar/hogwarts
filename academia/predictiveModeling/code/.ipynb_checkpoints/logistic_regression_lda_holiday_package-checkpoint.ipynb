# %% [markdown]
# <a href="https://colab.research.google.com/github/sarang-manohar/hogwarts/blob/main/academia/predictiveModeling/code/logistic_regression_lda_holiday_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


from sklearn.metrics import roc_auc_score, roc_curve, classification_report, confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
#os.chdir('/content/hogwarts/academia/predictiveModeling/data'); os.getcwd()

# %%
rd = pd.read_csv('../data/Holiday_Package.csv'); rd.head(10)
# Out:
#    Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0           1               no   48412   30     8                  1
# 1           2              yes   37207   45     8                  0
# 2           3               no   58022   46     9                  0
# 3           4               no   66503   31    11                  2
# 4           5               no   66734   44    12                  0
# 5           6              yes   61590   42    12                  0
# 6           7               no   94344   51     8                  0
# 7           8              yes   35987   32     8                  0
# 8           9               no   41140   39    12                  0
# 9          10               no   35826   43    11                  0
#
#    no_older_children foreign
# 0                  1      no
# 1                  1      no
# 2                  0      no
# 3                  0      no
# 4                  2      no
# 5                  1      no
# 6                  0      no
# 7                  2      no
# 8                  0      no
# 9                  2      no

# %%
#create a copy of dataframe
df = rd.copy(); df.head(1)
# Out:
#    Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0           1               no   48412   30     8                  1
#
#    no_older_children foreign
# 0                  1      no

# %%
#drop the unnamed column
df.drop('Unnamed: 0', axis =1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Holliday_Package   872 non-null    object
#  1   Salary             872 non-null    int64
#  2   age                872 non-null    int64
#  3   educ               872 non-null    int64
#  4   no_young_children  872 non-null    int64
#  5   no_older_children  872 non-null    int64
#  6   foreign            872 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 47.8+ KB

# %% [markdown]
# 1. There are no nulls in the data as observed from info results
# 2. Except for Holliday_Package and foreign, all the features are int which is as per expectations

# %%
df.describe()
# Out:
#               Salary         age        educ  no_young_children  \
# count     872.000000  872.000000  872.000000         872.000000
# mean    47729.172018   39.955275    9.307339           0.311927
# std     23418.668531   10.551675    3.036259           0.612870
# min      1322.000000   20.000000    1.000000           0.000000
# 25%     35324.000000   32.000000    8.000000           0.000000
# 50%     41903.500000   39.000000    9.000000           0.000000
# 75%     53469.500000   48.000000   12.000000           0.000000
# max    236961.000000   62.000000   21.000000           3.000000
#
#        no_older_children
# count         872.000000
# mean            0.982798
# std             1.086786
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             2.000000
# max             6.000000

# %%
df.skew()
# Out:
# Salary               3.103216
# age                  0.146412
# educ                -0.045501
# no_young_children    1.946515
# no_older_children    0.953951
# dtype: float64

# %% [markdown]
# 1. Except education, all the features are skewed and don't seemed to be normally ditributed

# %%
df['Holliday_Package'] = df['Holliday_Package'].map({'no':0,'yes':1})
df['Holliday_Package'] = df['Holliday_Package'].astype(int)

# %%
df['foreign'] = df['foreign'].map({'no':0,'yes':1})
df['foreign'] = df['foreign'].astype(int)

# %%
df.columns
# Out:
# Index(['Holliday_Package', 'Salary', 'age', 'educ', 'no_young_children',
#        'no_older_children', 'foreign'],
#       dtype='object')

# %%
from scipy.stats import shapiro as shapiro

for feature in ['Salary', 'age', 'educ', 'no_young_children','no_older_children']:
    stats, p_val = shapiro(df[feature])
    print('Normality test for', feature)
    print('Statitics = %.3f, p value = %.3f' % (stats, p_val))
    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    sns.kdeplot(ax=axes[0], data=df, x=feature,hue='Holliday_Package')
    sns.boxplot(ax=axes[1], data=df, y=feature, x='Holliday_Package')
    plt.show()
    if p_val > 0.05: print(feature, 'is normally distribution and has Gaussian curve.\n')
    else: print(feature, 'is not normally distributed.\n')
# Out:
# Normality test for Salary
# Statitics = 0.749, p value = 0.000
# Salary is not normally distributed.
#
# Normality test for age
# Statitics = 0.975, p value = 0.000
# age is not normally distributed.
#
# Normality test for educ
# Statitics = 0.976, p value = 0.000
# educ is not normally distributed.
#
# Normality test for no_young_children
# Statitics = 0.559, p value = 0.000
# no_young_children is not normally distributed.
#
# Normality test for no_older_children
# Statitics = 0.812, p value = 0.000
# no_older_children is not normally distributed.

# %%
dups = df.duplicated()
df[dups]
# Out:
# Empty DataFrame
# Columns: [Holliday_Package, Salary, age, educ, no_young_children, no_older_children, foreign]
# Index: []

# %%
sns.pairplot(data = df, diag_kind='kde',hue='Holliday_Package'); plt.show()

# %%
df_con = df[['Salary','age','educ']]

# %%
fig = plt.subplots(figsize=(10, 6))

corr = df_con.corr(method='pearson')
sns.heatmap(df_con.corr(), annot=True,fmt='.2f',cmap='Blues'); plt.show()

# %% [markdown]
# 1. There are only 3 continous variables and they don't seem to have any correlation among themselves

# %%
from sklearn.preprocessing import StandardScaler

df_lg = df.copy()
X_unscaled = df_lg.drop('Holliday_Package', axis=1)
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X_unscaled), columns = X_unscaled.columns)
y = df_lg.pop('Holliday_Package')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
importances = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X.columns)
importances['features'] = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
lgrg_model = LogisticRegression()
lgrg_model.fit(X_train,y_train)
lgrg_model
# Out:
# LogisticRegression()

# %%
lgrg_model.intercept_
# Out:
# array([-0.16977155])

# %%
col_1 = list()
col_2 = list()

for idx, col_name in enumerate(X_train.columns):
    col_1.append(col_name)
    col_2.append(lgrg_model.coef_[0][idx])

df_coef = pd.DataFrame.from_dict({'feature':col_1,'coef':col_2})

df_coef
# Out:
#              feature      coef
# 0             Salary -0.401822
# 1                age -0.562637
# 2               educ  0.229628
# 3  no_young_children -0.923030
# 4  no_older_children -0.055777
# 5            foreign  0.673796

# %%
ytrain_predict = lgrg_model.predict(X_train)
ytest_predict = lgrg_model.predict(X_test)

# %%
#Train data Confusion Matrix
print('Logistic Regression stats on train data:')
print(confusion_matrix(y_train, ytrain_predict))
#Train Data Accuracy
print('Accuracy score : %.1f percent' % (lgrg_model.score(X_train,y_train)*100) )
print(classification_report(y_train, ytrain_predict))
print('\n')
#Test data Confusion Matrix
print('Logistic Regression stats on test data:')
print(confusion_matrix(y_test, ytest_predict))
#Test Data Accuracy
print('Accuracy score : %.1f percent' % (lgrg_model.score(X_test,y_test)*100) )
print(classification_report(y_test, ytest_predict))
# Out:
# Logistic Regression stats on train data:
# [[252  74]
#  [121 163]]
# Accuracy score : 68.0 percent
#               precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72       326
#            1       0.69      0.57      0.63       284
#
#     accuracy                           0.68       610
#    macro avg       0.68      0.67      0.67       610
# weighted avg       0.68      0.68      0.68       610
#
#
#
# Logistic Regression stats on test data:
# [[102  43]
#  [ 52  65]]
# Accuracy score : 63.7 percent
#               precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68       145
#            1       0.60      0.56      0.58       117
#
#     accuracy                           0.64       262
#    macro avg       0.63      0.63      0.63       262
# weighted avg       0.64      0.64      0.64       262

# %%
train_prob = lgrg_model.predict_proba(X_train)[:,1]
train_auc = roc_auc_score(y_train, train_prob)
print('Area under ROC : %.1f percent' % (train_auc*100) )
fpr, tpr, thresholds = roc_curve(y_train, train_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for training data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 74.3 percent
# Best Threshold=0.464184, G-Mean=0.683

# %%
test_prob = lgrg_model.predict_proba(X_test)[:,1]
test_auc = roc_auc_score(y_test, test_prob)
print('Area under ROC : %.1f percent' % (test_auc*100) )
fpr, tpr, thresholds = roc_curve(y_test, test_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for test data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 70.5 percent
# Best Threshold=0.429592, G-Mean=0.687

# %%
lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train,y_train)
lda_model
# Out:
# LinearDiscriminantAnalysis()

# %%
ytrain_predict = lda_model.predict(X_train)
ytest_predict = lda_model.predict(X_test)

# %%
#Train data Confusion Matrix
print('Linear Discriminant Analysis stats on train data:')
print(confusion_matrix(y_train, ytrain_predict))
#Train Data Accuracy
print('Accuracy score : %.1f percent' % (lda_model.score(X_train,y_train)*100) )
print(classification_report(y_train, ytrain_predict))
print('\n')
#Test data Confusion Matrix
print('Linear Discriminant Analysis stats on test data:')
print(confusion_matrix(y_test, ytest_predict))
#Test Data Accuracy
print('Accuracy score : %.1f percent' % (lda_model.score(X_test,y_test)*100) )
print(classification_report(y_test, ytest_predict))
# Out:
# Linear Discriminant Analysis stats on train data:
# [[252  74]
#  [126 158]]
# Accuracy score : 67.2 percent
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.72       326
#            1       0.68      0.56      0.61       284
#
#     accuracy                           0.67       610
#    macro avg       0.67      0.66      0.66       610
# weighted avg       0.67      0.67      0.67       610
#
#
#
# Linear Discriminant Analysis stats on test data:
# [[103  42]
#  [ 52  65]]
# Accuracy score : 64.1 percent
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.69       145
#            1       0.61      0.56      0.58       117
#
#     accuracy                           0.64       262
#    macro avg       0.64      0.63      0.63       262
# weighted avg       0.64      0.64      0.64       262

# %%
train_prob = lda_model.predict_proba(X_train)[:,1]
train_auc = roc_auc_score(y_train, train_prob)
print('Area under ROC : %.1f percent' % (train_auc*100) )
fpr, tpr, thresholds = roc_curve(y_train, train_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for training data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 74.2 percent
# Best Threshold=0.440388, G-Mean=0.681

# %%
test_prob = lda_model.predict_proba(X_test)[:,1]
test_auc = roc_auc_score(y_test, test_prob)
print('Area under ROC : %.1f percent' % (test_auc*100) )
fpr, tpr, thresholds = roc_curve(y_test, test_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for test data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 70.3 percent
# Best Threshold=0.408121, G-Mean=0.687

# %% [markdown]
# # Feature engineering

# %%
df2 = df.copy()

# %%
df2.describe()
# Out:
#        Holliday_Package         Salary         age        educ  \
# count        872.000000     872.000000  872.000000  872.000000
# mean           0.459862   47729.172018   39.955275    9.307339
# std            0.498672   23418.668531   10.551675    3.036259
# min            0.000000    1322.000000   20.000000    1.000000
# 25%            0.000000   35324.000000   32.000000    8.000000
# 50%            0.000000   41903.500000   39.000000    9.000000
# 75%            1.000000   53469.500000   48.000000   12.000000
# max            1.000000  236961.000000   62.000000   21.000000
#
#        no_young_children  no_older_children     foreign
# count         872.000000         872.000000  872.000000
# mean            0.311927           0.982798    0.247706
# std             0.612870           1.086786    0.431928
# min             0.000000           0.000000    0.000000
# 25%             0.000000           0.000000    0.000000
# 50%             0.000000           1.000000    0.000000
# 75%             0.000000           2.000000    0.000000
# max             3.000000           6.000000    1.000000

# %%
df2['no_young_children'] = np.where(df2['no_young_children']>0,1,df['no_young_children'])

# %%
df2['no_older_children'] = np.where(df2['no_older_children']>0,1,df['no_older_children'])

# %%
df2['educ_ordinal'] = pd.cut(df2.educ, bins=[0,12,16,40], labels = [0,1,2])

# %%
df2.drop('educ', axis=1, inplace=True)

# %%
df2[df2['educ_ordinal']==2]
# Out:
#      Holliday_Package  Salary  age  no_young_children  no_older_children  \
# 20                  0   52059   29                  0                  0
# 74                  0   40904   44                  0                  1
# 217                 0   58451   30                  1                  0
# 253                 1  117276   51                  0                  1
# 434                 0   77421   34                  1                  0
# 547                 0   63833   51                  0                  1
# 638                 1   33126   32                  1                  0
#
#      foreign educ_ordinal
# 20         0            2
# 74         0            2
# 217        0            2
# 253        0            2
# 434        0            2
# 547        0            2
# 638        0            2

# %%
df_lg = df2.copy()
X_unscaled = df_lg.drop('Holliday_Package', axis=1)
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X_unscaled), columns = X_unscaled.columns)
y = df_lg.pop('Holliday_Package')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
importances = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X.columns)
importances['features'] = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='vertical')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
lgrg_model = LogisticRegression()
lgrg_model.fit(X_train,y_train)
lgrg_model
# Out:
# LogisticRegression()

# %%
lgrg_model.intercept_
# Out:
# array([-0.16355537])

# %%
col_1 = list()
col_2 = list()

for idx, col_name in enumerate(X_train.columns):
    col_1.append(col_name)
    col_2.append(lgrg_model.coef_[0][idx])

df_coef = pd.DataFrame.from_dict({'feature':col_1,'coef':col_2})

df_coef
# Out:
#              feature      coef
# 0             Salary -0.444983
# 1                age -0.641928
# 2  no_young_children -0.956193
# 3  no_older_children -0.036055
# 4            foreign  0.605069
# 5       educ_ordinal  0.372978

# %%
ytrain_predict = lgrg_model.predict(X_train)
ytest_predict = lgrg_model.predict(X_test)

# %%
#Train data Confusion Matrix
print('Logistic Regression stats on train data:')
print(confusion_matrix(y_train, ytrain_predict))
#Train Data Accuracy
print('Accuracy score : %.1f percent' % (lgrg_model.score(X_train,y_train)*100) )
print(classification_report(y_train, ytrain_predict))
print('\n')
#Test data Confusion Matrix
print('Logistic Regression stats on test data:')
print(confusion_matrix(y_test, ytest_predict))
#Test Data Accuracy
print('Accuracy score : %.1f percent' % (lgrg_model.score(X_test,y_test)*100) )
print(classification_report(y_test, ytest_predict))
# Out:
# Logistic Regression stats on train data:
# [[242  84]
#  [121 163]]
# Accuracy score : 66.4 percent
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       326
#            1       0.66      0.57      0.61       284
#
#     accuracy                           0.66       610
#    macro avg       0.66      0.66      0.66       610
# weighted avg       0.66      0.66      0.66       610
#
#
#
# Logistic Regression stats on test data:
# [[100  45]
#  [ 51  66]]
# Accuracy score : 63.4 percent
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.68       145
#            1       0.59      0.56      0.58       117
#
#     accuracy                           0.63       262
#    macro avg       0.63      0.63      0.63       262
# weighted avg       0.63      0.63      0.63       262

# %%
train_prob = lgrg_model.predict_proba(X_train)[:,1]
train_auc = roc_auc_score(y_train, train_prob)
print('Area under ROC : %.1f percent' % (train_auc*100) )
fpr, tpr, thresholds = roc_curve(y_train, train_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for training data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 75.5 percent
# Best Threshold=0.418256, G-Mean=0.677

# %%
test_prob = lgrg_model.predict_proba(X_test)[:,1]
test_auc = roc_auc_score(y_test, test_prob)
print('Area under ROC : %.1f percent' % (test_auc*100) )
fpr, tpr, thresholds = roc_curve(y_test, test_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for test data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 71.7 percent
# Best Threshold=0.408988, G-Mean=0.691

# %%
lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train,y_train)
lda_model
# Out:
# LinearDiscriminantAnalysis()

# %%
ytrain_predict = lda_model.predict(X_train)
ytest_predict = lda_model.predict(X_test)

# %%
#Train data Confusion Matrix
print('Linear Discriminant Analysis stats on train data:')
print(confusion_matrix(y_train, ytrain_predict))
#Train Data Accuracy
print('Accuracy score : %.1f percent' % (lda_model.score(X_train,y_train)*100) )
print(classification_report(y_train, ytrain_predict))
print('\n')
#Test data Confusion Matrix
print('Linear Discriminant Analysis stats on test data:')
print(confusion_matrix(y_test, ytest_predict))
#Test Data Accuracy
print('Accuracy score : %.1f percent' % (lda_model.score(X_test,y_test)*100) )
print(classification_report(y_test, ytest_predict))
# Out:
# Linear Discriminant Analysis stats on train data:
# [[244  82]
#  [122 162]]
# Accuracy score : 66.6 percent
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71       326
#            1       0.66      0.57      0.61       284
#
#     accuracy                           0.67       610
#    macro avg       0.67      0.66      0.66       610
# weighted avg       0.67      0.67      0.66       610
#
#
#
# Linear Discriminant Analysis stats on test data:
# [[103  42]
#  [ 52  65]]
# Accuracy score : 64.1 percent
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.69       145
#            1       0.61      0.56      0.58       117
#
#     accuracy                           0.64       262
#    macro avg       0.64      0.63      0.63       262
# weighted avg       0.64      0.64      0.64       262

# %%
train_prob = lda_model.predict_proba(X_train)[:,1]
train_auc = roc_auc_score(y_train, train_prob)
print('Area under ROC : %.1f percent' % (train_auc*100) )
fpr, tpr, thresholds = roc_curve(y_train, train_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for training data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 75.4 percent
# Best Threshold=0.395187, G-Mean=0.672

# %%
test_prob = lda_model.predict_proba(X_test)[:,1]
test_auc = roc_auc_score(y_test, test_prob)
print('Area under ROC : %.1f percent' % (test_auc*100) )
fpr, tpr, thresholds = roc_curve(y_test, test_prob)

# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for test data')
plt.legend()
# show the plot
plt.show()
# Out:
# Area under ROC : 71.1 percent
# Best Threshold=0.390290, G-Mean=0.682
