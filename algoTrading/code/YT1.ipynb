# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stock = yf.download("FINOLEXIND.BO", start = "2010-01-01",end ="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   56.549999   57.099998   53.099998   56.799999   52.447056
# 2010-01-05   57.450001   58.299999   56.299999   56.849998   52.493233
# 2010-01-06   57.500000   57.500000   56.150002   56.500000   52.170055
# 2010-01-07   56.900002   57.500000   56.500000   57.000000   52.631741
# 2010-01-08   59.000000   64.699997   58.099998   61.750000   57.017715
# ...                ...         ...         ...         ...         ...
# 2020-12-24  128.800003  128.800003  122.000000  122.889999  119.872917
# 2020-12-28  124.430000  129.270004  122.779999  128.830002  125.667091
# 2020-12-29  128.199997  131.940002  128.199997  128.990005  125.823174
# 2020-12-30  129.300003  130.600006  127.760002  129.289993  126.115791
# 2020-12-31  130.550003  130.789993  128.750000  129.300003  126.125549
#
#              Volume
# Date
# 2010-01-04   101270
# 2010-01-05   159029
# 2010-01-06    70466
# 2010-01-07    90726
# 2010-01-08  1423961
# ...             ...
# 2020-12-24    31310
# 2020-12-28   577265
# 2020-12-29    71840
# 2020-12-30    20270
# 2020-12-31    14830
#
# [2713 rows x 6 columns]

# %%
ticker=["FINOLEXIND.BO", "IBULHSGFIN.NS", "BANKBARODA.NS"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2021-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04     85.537788     52.447067           NaN    103.139999
# 2010-01-05     88.009209     52.493233           NaN    106.120003
# 2010-01-06     88.548271     52.170055           NaN    106.769997
# 2010-01-07     89.079056     52.631741           NaN    107.410004
# 2010-01-08     89.435654     57.017719           NaN    107.839996
# ...                  ...           ...           ...           ...
# 2020-12-24     59.071304    119.872917    196.439575     60.849998
# 2020-12-28     60.576000    125.667091    208.248978     62.400002
# 2020-12-29     60.527458    125.823174    207.384888     62.349998
# 2020-12-30     60.284767    126.115791    206.280762     62.099998
# 2020-12-31     59.653770    126.125549    211.513382     61.450001
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2010-01-04     56.799999           NaN    103.599998     57.099998
# 2010-01-05     56.849998           NaN    106.970001     58.299999
# 2010-01-06     56.500000           NaN    108.970001     57.500000
# 2010-01-07     57.000000           NaN    108.000000     57.500000
# 2010-01-08     61.750000           NaN    108.570000     64.699997
# ...                  ...           ...           ...           ...
# 2020-12-24    122.889999    204.600006     63.250000    128.800003
# 2020-12-28    128.830002    216.899994     62.950001    129.270004
# 2020-12-29    128.990005    216.000000     64.199997    131.940002
# 2020-12-30    129.289993    214.850006     63.250000    130.600006
# 2020-12-31    129.300003    220.300003     62.549999    130.789993
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04           NaN    101.110001     53.099998           NaN
# 2010-01-05           NaN    103.199997     56.299999           NaN
# 2010-01-06           NaN    104.430000     56.150002           NaN
# 2010-01-07           NaN    103.110001     56.500000           NaN
# 2010-01-08           NaN    107.000000     58.099998           NaN
# ...                  ...           ...           ...           ...
# 2020-12-24    209.600006     60.599998    122.000000    201.100006
# 2020-12-28    218.500000     61.250000    122.779999    205.399994
# 2020-12-29    220.550003     62.099998    128.199997    209.600006
# 2020-12-30    217.300003     60.750000    127.760002    211.350006
# 2020-12-31    223.500000     61.150002    128.750000    212.100006
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04    101.110001     56.549999           NaN       1164010
# 2010-01-05    106.970001     57.450001           NaN       3023360
# 2010-01-06    108.970001     57.500000           NaN       4283385
# 2010-01-07    103.110001     56.900002           NaN       1979305
# 2010-01-08    107.000000     59.000000           NaN       2956345
# ...                  ...           ...           ...           ...
# 2020-12-24     61.049999    128.800003    204.500000      39083563
# 2020-12-28     61.500000    124.430000    206.000000      27299489
# 2020-12-29     63.000000    128.199997    219.300003      41508873
# 2020-12-30     63.000000    129.300003    216.500000      33108560
# 2020-12-31     62.099998    130.550003    213.899994      22488846
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04        101270           NaN
# 2010-01-05        159029           NaN
# 2010-01-06         70466           NaN
# 2010-01-07         90726           NaN
# 2010-01-08       1423961           NaN
# ...                  ...           ...
# 2020-12-24         31310    23594132.0
# 2020-12-28        577265    31363853.0
# 2020-12-29         71840    30622206.0
# 2020-12-30         20270    15652743.0
# 2020-12-31         14830    27831642.0
#
# [2713 rows x 18 columns]

# %%
stocks.head()
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04     85.537788     52.447067           NaN    103.139999
# 2010-01-05     88.009209     52.493233           NaN    106.120003
# 2010-01-06     88.548271     52.170055           NaN    106.769997
# 2010-01-07     89.079056     52.631741           NaN    107.410004
# 2010-01-08     89.435654     57.017719           NaN    107.839996
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2010-01-04     56.799999           NaN    103.599998     57.099998
# 2010-01-05     56.849998           NaN    106.970001     58.299999
# 2010-01-06     56.500000           NaN    108.970001     57.500000
# 2010-01-07     57.000000           NaN    108.000000     57.500000
# 2010-01-08     61.750000           NaN    108.570000     64.699997
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04           NaN    101.110001     53.099998           NaN
# 2010-01-05           NaN    103.199997     56.299999           NaN
# 2010-01-06           NaN    104.430000     56.150002           NaN
# 2010-01-07           NaN    103.110001     56.500000           NaN
# 2010-01-08           NaN    107.000000     58.099998           NaN
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04    101.110001     56.549999           NaN       1164010
# 2010-01-05    106.970001     57.450001           NaN       3023360
# 2010-01-06    108.970001     57.500000           NaN       4283385
# 2010-01-07    103.110001     56.900002           NaN       1979305
# 2010-01-08    107.000000     59.000000           NaN       2956345
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04        101270           NaN
# 2010-01-05        159029           NaN
# 2010-01-06         70466           NaN
# 2010-01-07         90726           NaN
# 2010-01-08       1423961           NaN

# %%
stocks.tail()
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2020-12-24     59.071304    119.872917    196.439575     60.849998
# 2020-12-28     60.576000    125.667091    208.248978     62.400002
# 2020-12-29     60.527458    125.823174    207.384888     62.349998
# 2020-12-30     60.284767    126.115791    206.280762     62.099998
# 2020-12-31     59.653770    126.125549    211.513382     61.450001
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2020-12-24    122.889999    204.600006     63.250000    128.800003
# 2020-12-28    128.830002    216.899994     62.950001    129.270004
# 2020-12-29    128.990005    216.000000     64.199997    131.940002
# 2020-12-30    129.289993    214.850006     63.250000    130.600006
# 2020-12-31    129.300003    220.300003     62.549999    130.789993
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2020-12-24    209.600006     60.599998    122.000000    201.100006
# 2020-12-28    218.500000     61.250000    122.779999    205.399994
# 2020-12-29    220.550003     62.099998    128.199997    209.600006
# 2020-12-30    217.300003     60.750000    127.760002    211.350006
# 2020-12-31    223.500000     61.150002    128.750000    212.100006
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2020-12-24     61.049999    128.800003    204.500000      39083563
# 2020-12-28     61.500000    124.430000    206.000000      27299489
# 2020-12-29     63.000000    128.199997    219.300003      41508873
# 2020-12-30     63.000000    129.300003    216.500000      33108560
# 2020-12-31     62.099998    130.550003    213.899994      22488846
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2020-12-24         31310    23594132.0
# 2020-12-28        577265    31363853.0
# 2020-12-29         71840    30622206.0
# 2020-12-30         20270    15652743.0
# 2020-12-31         14830    27831642.0

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2713 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (Adj Close, BANKBARODA.NS)  2713 non-null   float64
#  1   (Adj Close, FINOLEXIND.BO)  2713 non-null   float64
#  2   (Adj Close, IBULHSGFIN.NS)  1832 non-null   float64
#  3   (Close, BANKBARODA.NS)      2713 non-null   float64
#  4   (Close, FINOLEXIND.BO)      2713 non-null   float64
#  5   (Close, IBULHSGFIN.NS)      1832 non-null   float64
#  6   (High, BANKBARODA.NS)       2713 non-null   float64
#  7   (High, FINOLEXIND.BO)       2713 non-null   float64
#  8   (High, IBULHSGFIN.NS)       1832 non-null   float64
#  9   (Low, BANKBARODA.NS)        2713 non-null   float64
#  10  (Low, FINOLEXIND.BO)        2713 non-null   float64
#  11  (Low, IBULHSGFIN.NS)        1832 non-null   float64
#  12  (Open, BANKBARODA.NS)       2713 non-null   float64
#  13  (Open, FINOLEXIND.BO)       2713 non-null   float64
#  14  (Open, IBULHSGFIN.NS)       1832 non-null   float64
#  15  (Volume, BANKBARODA.NS)     2713 non-null   int64
#  16  (Volume, FINOLEXIND.BO)     2713 non-null   int64
#  17  (Volume, IBULHSGFIN.NS)     1832 non-null   float64
# dtypes: float64(16), int64(2)
# memory usage: 402.7 KB

# %%
stocks.to_csv("stocksYT.csv")
# Out:
# /home/sarangm/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1        Adj Close.2  \
# 0            NaN       BANKBARODA.NS       FINOLEXIND.BO      IBULHSGFIN.NS
# 1           Date                 NaN                 NaN                NaN
# 2     2010-01-04   85.53778839111328   52.44706726074219                NaN
# 3     2010-01-05   88.00920867919922   52.49323272705078                NaN
# 4     2010-01-06   88.54827117919922    52.1700553894043                NaN
# ...          ...                 ...                 ...                ...
# 2710  2020-12-24   59.07130432128906  119.87291717529297  196.4395751953125
# 2711  2020-12-28   60.57600021362305   125.6670913696289  208.2489776611328
# 2712  2020-12-29   60.52745819091797  125.82317352294922  207.3848876953125
# 2713  2020-12-30  60.284767150878906  126.11579132080078    206.28076171875
# 2714  2020-12-31  59.653770446777344  126.12554931640625  211.5133819580078
#
#                    Close             Close.1             Close.2  \
# 0          BANKBARODA.NS       FINOLEXIND.BO       IBULHSGFIN.NS
# 1                    NaN                 NaN                 NaN
# 2     103.13999938964844   56.79999923706055                 NaN
# 3     106.12000274658203  56.849998474121094                 NaN
# 4      106.7699966430664                56.5                 NaN
# ...                  ...                 ...                 ...
# 2710  60.849998474121094  122.88999938964844  204.60000610351562
# 2711  62.400001525878906   128.8300018310547  216.89999389648438
# 2712  62.349998474121094  128.99000549316406               216.0
# 2713  62.099998474121094   129.2899932861328  214.85000610351562
# 2714   61.45000076293945   129.3000030517578   220.3000030517578
#
#                     High              High.1              High.2  \
# 0          BANKBARODA.NS       FINOLEXIND.BO       IBULHSGFIN.NS
# 1                    NaN                 NaN                 NaN
# 2      103.5999984741211  57.099998474121094                 NaN
# 3     106.97000122070312   58.29999923706055                 NaN
# 4     108.97000122070312                57.5                 NaN
# ...                  ...                 ...                 ...
# 2710               63.25   128.8000030517578  209.60000610351562
# 2711   62.95000076293945  129.27000427246094               218.5
# 2712   64.19999694824219  131.94000244140625   220.5500030517578
# 2713               63.25  130.60000610351562   217.3000030517578
# 2714   62.54999923706055   130.7899932861328               223.5
#
#                      Low               Low.1               Low.2  \
# 0          BANKBARODA.NS       FINOLEXIND.BO       IBULHSGFIN.NS
# 1                    NaN                 NaN                 NaN
# 2     101.11000061035156  53.099998474121094                 NaN
# 3     103.19999694824219   56.29999923706055                 NaN
# 4     104.43000030517578  56.150001525878906                 NaN
# ...                  ...                 ...                 ...
# 2710  60.599998474121094               122.0  201.10000610351562
# 2711               61.25  122.77999877929688  205.39999389648438
# 2712  62.099998474121094   128.1999969482422  209.60000610351562
# 2713               60.75  127.76000213623047  211.35000610351562
# 2714  61.150001525878906              128.75  212.10000610351562
#
#                     Open              Open.1              Open.2  \
# 0          BANKBARODA.NS       FINOLEXIND.BO       IBULHSGFIN.NS
# 1                    NaN                 NaN                 NaN
# 2     101.11000061035156   56.54999923706055                 NaN
# 3     106.97000122070312   57.45000076293945                 NaN
# 4     108.97000122070312                57.5                 NaN
# ...                  ...                 ...                 ...
# 2710   61.04999923706055   128.8000030517578               204.5
# 2711                61.5  124.43000030517578               206.0
# 2712                63.0   128.1999969482422   219.3000030517578
# 2713                63.0   129.3000030517578               216.5
# 2714  62.099998474121094   130.5500030517578  213.89999389648438
#
#              Volume       Volume.1       Volume.2
# 0     BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# 1               NaN            NaN            NaN
# 2           1164010         101270            NaN
# 3           3023360         159029            NaN
# 4           4283385          70466            NaN
# ...             ...            ...            ...
# 2710       39083563          31310     23594132.0
# 2711       27299489         577265     31363853.0
# 2712       41508873          71840     30622206.0
# 2713       33108560          20270     15652743.0
# 2714       22488846          14830     27831642.0
#
# [2715 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0     Adj Close                              \
#      Unnamed: 0_level_1 BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# 0                  Date           NaN           NaN           NaN
# 1            2010-01-04     85.537788     52.447067           NaN
# 2            2010-01-05     88.009209     52.493233           NaN
# 3            2010-01-06     88.548271     52.170055           NaN
# 4            2010-01-07     89.079056     52.631741           NaN
# ...                 ...           ...           ...           ...
# 2709         2020-12-24     59.071304    119.872917    196.439575
# 2710         2020-12-28     60.576000    125.667091    208.248978
# 2711         2020-12-29     60.527458    125.823174    207.384888
# 2712         2020-12-30     60.284767    126.115791    206.280762
# 2713         2020-12-31     59.653770    126.125549    211.513382
#
#              Close                                      High                \
#      BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# 0              NaN           NaN           NaN           NaN           NaN
# 1       103.139999     56.799999           NaN    103.599998     57.099998
# 2       106.120003     56.849998           NaN    106.970001     58.299999
# 3       106.769997     56.500000           NaN    108.970001     57.500000
# 4       107.410004     57.000000           NaN    108.000000     57.500000
# ...            ...           ...           ...           ...           ...
# 2709     60.849998    122.889999    204.600006     63.250000    128.800003
# 2710     62.400002    128.830002    216.899994     62.950001    129.270004
# 2711     62.349998    128.990005    216.000000     64.199997    131.940002
# 2712     62.099998    129.289993    214.850006     63.250000    130.600006
# 2713     61.450001    129.300003    220.300003     62.549999    130.789993
#
#                              Low                                      Open  \
#      IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN    101.110001     53.099998           NaN    101.110001
# 2              NaN    103.199997     56.299999           NaN    106.970001
# 3              NaN    104.430000     56.150002           NaN    108.970001
# 4              NaN    103.110001     56.500000           NaN    103.110001
# ...            ...           ...           ...           ...           ...
# 2709    209.600006     60.599998    122.000000    201.100006     61.049999
# 2710    218.500000     61.250000    122.779999    205.399994     61.500000
# 2711    220.550003     62.099998    128.199997    209.600006     63.000000
# 2712    217.300003     60.750000    127.760002    211.350006     63.000000
# 2713    223.500000     61.150002    128.750000    212.100006     62.099998
#
#                                         Volume
#      FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# 0              NaN           NaN           NaN           NaN           NaN
# 1        56.549999           NaN     1164010.0      101270.0           NaN
# 2        57.450001           NaN     3023360.0      159029.0           NaN
# 3        57.500000           NaN     4283385.0       70466.0           NaN
# 4        56.900002           NaN     1979305.0       90726.0           NaN
# ...            ...           ...           ...           ...           ...
# 2709    128.800003    204.500000    39083563.0       31310.0    23594132.0
# 2710    124.430000    206.000000    27299489.0      577265.0    31363853.0
# 2711    128.199997    219.300003    41508873.0       71840.0    30622206.0
# 2712    129.300003    216.500000    33108560.0       20270.0    15652743.0
# 2713    130.550003    213.899994    22488846.0       14830.0    27831642.0
#
# [2714 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0])
stocks
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04     85.537788     52.447067           NaN    103.139999
# 2010-01-05     88.009209     52.493233           NaN    106.120003
# 2010-01-06     88.548271     52.170055           NaN    106.769997
# 2010-01-07     89.079056     52.631741           NaN    107.410004
# 2010-01-08     89.435654     57.017719           NaN    107.839996
# ...                  ...           ...           ...           ...
# 2020-12-24     59.071304    119.872917    196.439575     60.849998
# 2020-12-28     60.576000    125.667091    208.248978     62.400002
# 2020-12-29     60.527458    125.823174    207.384888     62.349998
# 2020-12-30     60.284767    126.115791    206.280762     62.099998
# 2020-12-31     59.653770    126.125549    211.513382     61.450001
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2010-01-04     56.799999           NaN    103.599998     57.099998
# 2010-01-05     56.849998           NaN    106.970001     58.299999
# 2010-01-06     56.500000           NaN    108.970001     57.500000
# 2010-01-07     57.000000           NaN    108.000000     57.500000
# 2010-01-08     61.750000           NaN    108.570000     64.699997
# ...                  ...           ...           ...           ...
# 2020-12-24    122.889999    204.600006     63.250000    128.800003
# 2020-12-28    128.830002    216.899994     62.950001    129.270004
# 2020-12-29    128.990005    216.000000     64.199997    131.940002
# 2020-12-30    129.289993    214.850006     63.250000    130.600006
# 2020-12-31    129.300003    220.300003     62.549999    130.789993
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04           NaN    101.110001     53.099998           NaN
# 2010-01-05           NaN    103.199997     56.299999           NaN
# 2010-01-06           NaN    104.430000     56.150002           NaN
# 2010-01-07           NaN    103.110001     56.500000           NaN
# 2010-01-08           NaN    107.000000     58.099998           NaN
# ...                  ...           ...           ...           ...
# 2020-12-24    209.600006     60.599998    122.000000    201.100006
# 2020-12-28    218.500000     61.250000    122.779999    205.399994
# 2020-12-29    220.550003     62.099998    128.199997    209.600006
# 2020-12-30    217.300003     60.750000    127.760002    211.350006
# 2020-12-31    223.500000     61.150002    128.750000    212.100006
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04    101.110001     56.549999           NaN       1164010
# 2010-01-05    106.970001     57.450001           NaN       3023360
# 2010-01-06    108.970001     57.500000           NaN       4283385
# 2010-01-07    103.110001     56.900002           NaN       1979305
# 2010-01-08    107.000000     59.000000           NaN       2956345
# ...                  ...           ...           ...           ...
# 2020-12-24     61.049999    128.800003    204.500000      39083563
# 2020-12-28     61.500000    124.430000    206.000000      27299489
# 2020-12-29     63.000000    128.199997    219.300003      41508873
# 2020-12-30     63.000000    129.300003    216.500000      33108560
# 2020-12-31     62.099998    130.550003    213.899994      22488846
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04        101270           NaN
# 2010-01-05        159029           NaN
# 2010-01-06         70466           NaN
# 2010-01-07         90726           NaN
# 2010-01-08       1423961           NaN
# ...                  ...           ...
# 2020-12-24         31310    23594132.0
# 2020-12-28        577265    31363853.0
# 2020-12-29         71840    30622206.0
# 2020-12-30         20270    15652743.0
# 2020-12-31         14830    27831642.0
#
# [2713 rows x 18 columns]

# %%
stocks = pd.read_csv("stocksYT.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04     85.537788     52.447067           NaN    103.139999
# 2010-01-05     88.009209     52.493233           NaN    106.120003
# 2010-01-06     88.548271     52.170055           NaN    106.769997
# 2010-01-07     89.079056     52.631741           NaN    107.410004
# 2010-01-08     89.435654     57.017719           NaN    107.839996
# ...                  ...           ...           ...           ...
# 2020-12-24     59.071304    119.872917    196.439575     60.849998
# 2020-12-28     60.576000    125.667091    208.248978     62.400002
# 2020-12-29     60.527458    125.823174    207.384888     62.349998
# 2020-12-30     60.284767    126.115791    206.280762     62.099998
# 2020-12-31     59.653770    126.125549    211.513382     61.450001
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2010-01-04     56.799999           NaN    103.599998     57.099998
# 2010-01-05     56.849998           NaN    106.970001     58.299999
# 2010-01-06     56.500000           NaN    108.970001     57.500000
# 2010-01-07     57.000000           NaN    108.000000     57.500000
# 2010-01-08     61.750000           NaN    108.570000     64.699997
# ...                  ...           ...           ...           ...
# 2020-12-24    122.889999    204.600006     63.250000    128.800003
# 2020-12-28    128.830002    216.899994     62.950001    129.270004
# 2020-12-29    128.990005    216.000000     64.199997    131.940002
# 2020-12-30    129.289993    214.850006     63.250000    130.600006
# 2020-12-31    129.300003    220.300003     62.549999    130.789993
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04           NaN    101.110001     53.099998           NaN
# 2010-01-05           NaN    103.199997     56.299999           NaN
# 2010-01-06           NaN    104.430000     56.150002           NaN
# 2010-01-07           NaN    103.110001     56.500000           NaN
# 2010-01-08           NaN    107.000000     58.099998           NaN
# ...                  ...           ...           ...           ...
# 2020-12-24    209.600006     60.599998    122.000000    201.100006
# 2020-12-28    218.500000     61.250000    122.779999    205.399994
# 2020-12-29    220.550003     62.099998    128.199997    209.600006
# 2020-12-30    217.300003     60.750000    127.760002    211.350006
# 2020-12-31    223.500000     61.150002    128.750000    212.100006
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04    101.110001     56.549999           NaN       1164010
# 2010-01-05    106.970001     57.450001           NaN       3023360
# 2010-01-06    108.970001     57.500000           NaN       4283385
# 2010-01-07    103.110001     56.900002           NaN       1979305
# 2010-01-08    107.000000     59.000000           NaN       2956345
# ...                  ...           ...           ...           ...
# 2020-12-24     61.049999    128.800003    204.500000      39083563
# 2020-12-28     61.500000    124.430000    206.000000      27299489
# 2020-12-29     63.000000    128.199997    219.300003      41508873
# 2020-12-30     63.000000    129.300003    216.500000      33108560
# 2020-12-31     62.099998    130.550003    213.899994      22488846
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04        101270           NaN
# 2010-01-05        159029           NaN
# 2010-01-06         70466           NaN
# 2010-01-07         90726           NaN
# 2010-01-08       1423961           NaN
# ...                  ...           ...
# 2020-12-24         31310    23594132.0
# 2020-12-28        577265    31363853.0
# 2020-12-29         71840    30622206.0
# 2020-12-30         20270    15652743.0
# 2020-12-31         14830    27831642.0
#
# [2713 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'BANKBARODA.NS'),
#             ('Adj Close', 'FINOLEXIND.BO'),
#             ('Adj Close', 'IBULHSGFIN.NS'),
#             (    'Close', 'BANKBARODA.NS'),
#             (    'Close', 'FINOLEXIND.BO'),
#             (    'Close', 'IBULHSGFIN.NS'),
#             (     'High', 'BANKBARODA.NS'),
#             (     'High', 'FINOLEXIND.BO'),
#             (     'High', 'IBULHSGFIN.NS'),
#             (      'Low', 'BANKBARODA.NS'),
#             (      'Low', 'FINOLEXIND.BO'),
#             (      'Low', 'IBULHSGFIN.NS'),
#             (     'Open', 'BANKBARODA.NS'),
#             (     'Open', 'FINOLEXIND.BO'),
#             (     'Open', 'IBULHSGFIN.NS'),
#             (   'Volume', 'BANKBARODA.NS'),
#             (   'Volume', 'FINOLEXIND.BO'),
#             (   'Volume', 'IBULHSGFIN.NS')],
#            )

# %%
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'BANKBARODA.NS'), ('Adj Close', 'FINOLEXIND.BO'),
#        ('Adj Close', 'IBULHSGFIN.NS'),     ('Close', 'BANKBARODA.NS'),
#            ('Close', 'FINOLEXIND.BO'),     ('Close', 'IBULHSGFIN.NS'),
#             ('High', 'BANKBARODA.NS'),      ('High', 'FINOLEXIND.BO'),
#             ('High', 'IBULHSGFIN.NS'),       ('Low', 'BANKBARODA.NS'),
#              ('Low', 'FINOLEXIND.BO'),       ('Low', 'IBULHSGFIN.NS'),
#             ('Open', 'BANKBARODA.NS'),      ('Open', 'FINOLEXIND.BO'),
#             ('Open', 'IBULHSGFIN.NS'),    ('Volume', 'BANKBARODA.NS'),
#           ('Volume', 'FINOLEXIND.BO'),    ('Volume', 'IBULHSGFIN.NS')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, BANKBARODA.NS)  (Adj Close, FINOLEXIND.BO)  \
# Date
# 2010-01-04                   85.537788                   52.447067
# 2010-01-05                   88.009209                   52.493233
# 2010-01-06                   88.548271                   52.170055
# 2010-01-07                   89.079056                   52.631741
# 2010-01-08                   89.435654                   57.017719
# ...                                ...                         ...
# 2020-12-24                   59.071304                  119.872917
# 2020-12-28                   60.576000                  125.667091
# 2020-12-29                   60.527458                  125.823174
# 2020-12-30                   60.284767                  126.115791
# 2020-12-31                   59.653770                  126.125549
#
#             (Adj Close, IBULHSGFIN.NS)  (Close, BANKBARODA.NS)  \
# Date
# 2010-01-04                         NaN              103.139999
# 2010-01-05                         NaN              106.120003
# 2010-01-06                         NaN              106.769997
# 2010-01-07                         NaN              107.410004
# 2010-01-08                         NaN              107.839996
# ...                                ...                     ...
# 2020-12-24                  196.439575               60.849998
# 2020-12-28                  208.248978               62.400002
# 2020-12-29                  207.384888               62.349998
# 2020-12-30                  206.280762               62.099998
# 2020-12-31                  211.513382               61.450001
#
#             (Close, FINOLEXIND.BO)  (Close, IBULHSGFIN.NS)  \
# Date
# 2010-01-04               56.799999                     NaN
# 2010-01-05               56.849998                     NaN
# 2010-01-06               56.500000                     NaN
# 2010-01-07               57.000000                     NaN
# 2010-01-08               61.750000                     NaN
# ...                            ...                     ...
# 2020-12-24              122.889999              204.600006
# 2020-12-28              128.830002              216.899994
# 2020-12-29              128.990005              216.000000
# 2020-12-30              129.289993              214.850006
# 2020-12-31              129.300003              220.300003
#
#             (High, BANKBARODA.NS)  (High, FINOLEXIND.BO)  \
# Date
# 2010-01-04             103.599998              57.099998
# 2010-01-05             106.970001              58.299999
# 2010-01-06             108.970001              57.500000
# 2010-01-07             108.000000              57.500000
# 2010-01-08             108.570000              64.699997
# ...                           ...                    ...
# 2020-12-24              63.250000             128.800003
# 2020-12-28              62.950001             129.270004
# 2020-12-29              64.199997             131.940002
# 2020-12-30              63.250000             130.600006
# 2020-12-31              62.549999             130.789993
#
#             (High, IBULHSGFIN.NS)  (Low, BANKBARODA.NS)  (Low, FINOLEXIND.BO)  \
# Date
# 2010-01-04                    NaN            101.110001             53.099998
# 2010-01-05                    NaN            103.199997             56.299999
# 2010-01-06                    NaN            104.430000             56.150002
# 2010-01-07                    NaN            103.110001             56.500000
# 2010-01-08                    NaN            107.000000             58.099998
# ...                           ...                   ...                   ...
# 2020-12-24             209.600006             60.599998            122.000000
# 2020-12-28             218.500000             61.250000            122.779999
# 2020-12-29             220.550003             62.099998            128.199997
# 2020-12-30             217.300003             60.750000            127.760002
# 2020-12-31             223.500000             61.150002            128.750000
#
#             (Low, IBULHSGFIN.NS)  (Open, BANKBARODA.NS)  \
# Date
# 2010-01-04                   NaN             101.110001
# 2010-01-05                   NaN             106.970001
# 2010-01-06                   NaN             108.970001
# 2010-01-07                   NaN             103.110001
# 2010-01-08                   NaN             107.000000
# ...                          ...                    ...
# 2020-12-24            201.100006              61.049999
# 2020-12-28            205.399994              61.500000
# 2020-12-29            209.600006              63.000000
# 2020-12-30            211.350006              63.000000
# 2020-12-31            212.100006              62.099998
#
#             (Open, FINOLEXIND.BO)  (Open, IBULHSGFIN.NS)  \
# Date
# 2010-01-04              56.549999                    NaN
# 2010-01-05              57.450001                    NaN
# 2010-01-06              57.500000                    NaN
# 2010-01-07              56.900002                    NaN
# 2010-01-08              59.000000                    NaN
# ...                           ...                    ...
# 2020-12-24             128.800003             204.500000
# 2020-12-28             124.430000             206.000000
# 2020-12-29             128.199997             219.300003
# 2020-12-30             129.300003             216.500000
# 2020-12-31             130.550003             213.899994
#
#             (Volume, BANKBARODA.NS)  (Volume, FINOLEXIND.BO)  \
# Date
# 2010-01-04                  1164010                   101270
# 2010-01-05                  3023360                   159029
# 2010-01-06                  4283385                    70466
# 2010-01-07                  1979305                    90726
# 2010-01-08                  2956345                  1423961
# ...                             ...                      ...
# 2020-12-24                 39083563                    31310
# 2020-12-28                 27299489                   577265
# 2020-12-29                 41508873                    71840
# 2020-12-30                 33108560                    20270
# 2020-12-31                 22488846                    14830
#
#             (Volume, IBULHSGFIN.NS)
# Date
# 2010-01-04                      NaN
# 2010-01-05                      NaN
# 2010-01-06                      NaN
# 2010-01-07                      NaN
# 2010-01-08                      NaN
# ...                             ...
# 2020-12-24               23594132.0
# 2020-12-28               31363853.0
# 2020-12-29               30622206.0
# 2020-12-30               15652743.0
# 2020-12-31               27831642.0
#
# [2713 rows x 18 columns]

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#                Adj Close                                     Close  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04     85.537788     52.447067           NaN    103.139999
# 2010-01-05     88.009209     52.493233           NaN    106.120003
# 2010-01-06     88.548271     52.170055           NaN    106.769997
# 2010-01-07     89.079056     52.631741           NaN    107.410004
# 2010-01-08     89.435654     57.017719           NaN    107.839996
# ...                  ...           ...           ...           ...
# 2020-12-24     59.071304    119.872917    196.439575     60.849998
# 2020-12-28     60.576000    125.667091    208.248978     62.400002
# 2020-12-29     60.527458    125.823174    207.384888     62.349998
# 2020-12-30     60.284767    126.115791    206.280762     62.099998
# 2020-12-31     59.653770    126.125549    211.513382     61.450001
#
#                                                 High                \
#            FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# Date
# 2010-01-04     56.799999           NaN    103.599998     57.099998
# 2010-01-05     56.849998           NaN    106.970001     58.299999
# 2010-01-06     56.500000           NaN    108.970001     57.500000
# 2010-01-07     57.000000           NaN    108.000000     57.500000
# 2010-01-08     61.750000           NaN    108.570000     64.699997
# ...                  ...           ...           ...           ...
# 2020-12-24    122.889999    204.600006     63.250000    128.800003
# 2020-12-28    128.830002    216.899994     62.950001    129.270004
# 2020-12-29    128.990005    216.000000     64.199997    131.940002
# 2020-12-30    129.289993    214.850006     63.250000    130.600006
# 2020-12-31    129.300003    220.300003     62.549999    130.789993
#
#                                    Low                              \
#            IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04           NaN    101.110001     53.099998           NaN
# 2010-01-05           NaN    103.199997     56.299999           NaN
# 2010-01-06           NaN    104.430000     56.150002           NaN
# 2010-01-07           NaN    103.110001     56.500000           NaN
# 2010-01-08           NaN    107.000000     58.099998           NaN
# ...                  ...           ...           ...           ...
# 2020-12-24    209.600006     60.599998    122.000000    201.100006
# 2020-12-28    218.500000     61.250000    122.779999    205.399994
# 2020-12-29    220.550003     62.099998    128.199997    209.600006
# 2020-12-30    217.300003     60.750000    127.760002    211.350006
# 2020-12-31    223.500000     61.150002    128.750000    212.100006
#
#                     Open                                    Volume  \
#            BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# Date
# 2010-01-04    101.110001     56.549999           NaN       1164010
# 2010-01-05    106.970001     57.450001           NaN       3023360
# 2010-01-06    108.970001     57.500000           NaN       4283385
# 2010-01-07    103.110001     56.900002           NaN       1979305
# 2010-01-08    107.000000     59.000000           NaN       2956345
# ...                  ...           ...           ...           ...
# 2020-12-24     61.049999    128.800003    204.500000      39083563
# 2020-12-28     61.500000    124.430000    206.000000      27299489
# 2020-12-29     63.000000    128.199997    219.300003      41508873
# 2020-12-30     63.000000    129.300003    216.500000      33108560
# 2020-12-31     62.099998    130.550003    213.899994      22488846
#
#
#            FINOLEXIND.BO IBULHSGFIN.NS
# Date
# 2010-01-04        101270           NaN
# 2010-01-05        159029           NaN
# 2010-01-06         70466           NaN
# 2010-01-07         90726           NaN
# 2010-01-08       1423961           NaN
# ...                  ...           ...
# 2020-12-24         31310    23594132.0
# 2020-12-28        577265    31363853.0
# 2020-12-29         71840    30622206.0
# 2020-12-30         20270    15652743.0
# 2020-12-31         14830    27831642.0
#
# [2713 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'BANKBARODA.NS'),
#             ('Adj Close', 'FINOLEXIND.BO'),
#             ('Adj Close', 'IBULHSGFIN.NS'),
#             (    'Close', 'BANKBARODA.NS'),
#             (    'Close', 'FINOLEXIND.BO'),
#             (    'Close', 'IBULHSGFIN.NS'),
#             (     'High', 'BANKBARODA.NS'),
#             (     'High', 'FINOLEXIND.BO'),
#             (     'High', 'IBULHSGFIN.NS'),
#             (      'Low', 'BANKBARODA.NS'),
#             (      'Low', 'FINOLEXIND.BO'),
#             (      'Low', 'IBULHSGFIN.NS'),
#             (     'Open', 'BANKBARODA.NS'),
#             (     'Open', 'FINOLEXIND.BO'),
#             (     'Open', 'IBULHSGFIN.NS'),
#             (   'Volume', 'BANKBARODA.NS'),
#             (   'Volume', 'FINOLEXIND.BO'),
#             (   'Volume', 'IBULHSGFIN.NS')],
#            )

# %%
stocks.describe()
# Out:
#           Adj Close                                     Close                \
#       BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO
# count   2713.000000   2713.000000   1832.000000   2713.000000   2713.000000
# mean     129.837433    279.783411    521.286497    140.542886    290.982072
# std       34.671262    203.791903    304.284700     37.914407    210.217811
# min       35.433075     39.535225     86.170341     36.500000     42.200001
# 25%      111.541382     84.680061    253.093994    120.550003     89.970001
# 50%      134.791306    256.814880    518.992676    146.470001    268.700012
# 75%      154.014221    484.309814    700.852310    167.660004    500.600006
# max      212.547394    708.901306   1182.019531    225.580002    734.799988
#
#                              High                                       Low  \
#       IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS
# count   1832.000000   2713.000000   2713.000000   1832.000000   2713.000000
# mean     639.044022    143.110689    296.119437    652.201284    138.178319
# std      358.709091     38.430021    213.326254    362.816160     37.427399
# min       89.750000     37.200001     43.349998     92.849998     36.000000
# 25%      298.574989    122.699997     91.800003    307.925011    118.099998
# 50%      649.475006    149.000000    273.250000    661.975006    144.309998
# 75%      831.824997    170.050003    508.649994    847.824997    165.009995
# max     1421.150024    228.899994    752.799988   1440.000000    221.100006
#
#                                            Open                              \
#       FINOLEXIND.BO IBULHSGFIN.NS BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# count   2713.000000   1832.000000   2713.000000   2713.000000   1832.000000
# mean     286.711669    626.782396    140.700487    291.894150    640.103521
# std      207.862110    354.445006     37.982158    211.020898    359.344489
# min        0.010000     81.000000     36.150002     42.549999     81.750000
# 25%       88.349998    290.325005    120.500000     90.000000    298.724998
# 50%      264.000000    633.924988    146.750000    268.600006    650.000000
# 75%      495.299988    817.087494    167.899994    502.399994    835.050003
# max      720.000000   1408.550049    228.399994    742.000000   1426.550049
#
#              Volume
#       BANKBARODA.NS FINOLEXIND.BO IBULHSGFIN.NS
# count  2.713000e+03  2.713000e+03  1.832000e+03
# mean   1.132736e+07  5.553381e+04  8.245859e+06
# std    1.318854e+07  1.449672e+05  1.564113e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.365805e+06  5.303000e+03  8.789490e+05
# 50%    6.967455e+06  1.448800e+04  1.639754e+06
# 75%    1.428040e+07  4.019800e+04  8.485656e+06
# max    1.448919e+08  3.032490e+06  1.734092e+08

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#             BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# Date
# 2010-01-04     103.139999      56.799999            NaN
# 2010-01-05     106.120003      56.849998            NaN
# 2010-01-06     106.769997      56.500000            NaN
# 2010-01-07     107.410004      57.000000            NaN
# 2010-01-08     107.839996      61.750000            NaN
# ...                   ...            ...            ...
# 2020-12-24      60.849998     122.889999     204.600006
# 2020-12-28      62.400002     128.830002     216.899994
# 2020-12-29      62.349998     128.990005     216.000000
# 2020-12-30      62.099998     129.289993     214.850006
# 2020-12-31      61.450001     129.300003     220.300003
#
# [2713 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /tmp/ipykernel_135931/715908909.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 103.13999938964844

# %%
close["FINOLEXIND.BO"]
# Out:
# Date
# 2010-01-04     56.799999
# 2010-01-05     56.849998
# 2010-01-06     56.500000
# 2010-01-07     57.000000
# 2010-01-08     61.750000
#                  ...
# 2020-12-24    122.889999
# 2020-12-28    128.830002
# 2020-12-29    128.990005
# 2020-12-30    129.289993
# 2020-12-31    129.300003
# Name: FINOLEXIND.BO, Length: 2713, dtype: float64

# %%
close["FINOLEXIND.BO"].div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04    0.550708
# 2010-01-05    0.551193
# 2010-01-06    0.547799
# 2010-01-07    0.552647
# 2010-01-08    0.598701
#                 ...
# 2020-12-24    1.191487
# 2020-12-28    1.249079
# 2020-12-29    1.250630
# 2020-12-30    1.253539
# 2020-12-31    1.253636
# Name: FINOLEXIND.BO, Length: 2713, dtype: float64

# %%
close["FINOLEXIND.BO"].div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     55.070777
# 2010-01-05     55.119254
# 2010-01-06     54.779911
# 2010-01-07     55.264689
# 2010-01-08     59.870080
#                  ...
# 2020-12-24    119.148730
# 2020-12-28    124.907895
# 2020-12-29    125.063027
# 2020-12-30    125.353882
# 2020-12-31    125.363587
# Name: FINOLEXIND.BO, Length: 2713, dtype: float64

# %%
close.iloc[0]
# Out:
# BANKBARODA.NS    103.139999
# FINOLEXIND.BO     56.799999
# IBULHSGFIN.NS           NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#             BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# Date
# 2010-01-04     100.000000     100.000000            NaN
# 2010-01-05     102.889280     100.088027            NaN
# 2010-01-06     103.519485      99.471832            NaN
# 2010-01-07     104.140008     100.352114            NaN
# 2010-01-08     104.556910     108.714790            NaN
# ...                   ...            ...            ...
# 2020-12-24      58.997478     216.355636            NaN
# 2020-12-28      60.500293     226.813387            NaN
# 2020-12-29      60.451812     227.095083            NaN
# 2020-12-30      60.209423     227.623231            NaN
# 2020-12-31      59.579214     227.640854            NaN
#
# [2713 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
stck = close["FINOLEXIND.BO"].copy().to_frame()

# %%
stck
# Out:
#             FINOLEXIND.BO
# Date
# 2010-01-04      56.799999
# 2010-01-05      56.849998
# 2010-01-06      56.500000
# 2010-01-07      57.000000
# 2010-01-08      61.750000
# ...                   ...
# 2020-12-24     122.889999
# 2020-12-28     128.830002
# 2020-12-29     128.990005
# 2020-12-30     129.289993
# 2020-12-31     129.300003
#
# [2713 rows x 1 columns]

# %%
stck.shift(periods=1)
# Out:
#             FINOLEXIND.BO
# Date
# 2010-01-04            NaN
# 2010-01-05      56.799999
# 2010-01-06      56.849998
# 2010-01-07      56.500000
# 2010-01-08      57.000000
# ...                   ...
# 2020-12-24     124.330002
# 2020-12-28     122.889999
# 2020-12-29     128.830002
# 2020-12-30     128.990005
# 2020-12-31     129.289993
#
# [2713 rows x 1 columns]

# %%
stck["lag1"]=stck.shift(periods=1)

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1
# Date
# 2010-01-04      56.799999         NaN
# 2010-01-05      56.849998   56.799999
# 2010-01-06      56.500000   56.849998
# 2010-01-07      57.000000   56.500000
# 2010-01-08      61.750000   57.000000
# ...                   ...         ...
# 2020-12-24     122.889999  124.330002
# 2020-12-28     128.830002  122.889999
# 2020-12-29     128.990005  128.830002
# 2020-12-30     129.289993  128.990005
# 2020-12-31     129.300003  129.289993
#
# [2713 rows x 2 columns]

# %%
stck["Diff"]=stck["FINOLEXIND.BO"].sub(stck.lag1)

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff
# Date
# 2010-01-04      56.799999         NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999
# 2010-01-06      56.500000   56.849998 -0.349998
# 2010-01-07      57.000000   56.500000  0.500000
# 2010-01-08      61.750000   57.000000  4.750000
# ...                   ...         ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002
# 2020-12-28     128.830002  122.889999  5.940002
# 2020-12-29     128.990005  128.830002  0.160004
# 2020-12-30     129.289993  128.990005  0.299988
# 2020-12-31     129.300003  129.289993  0.010010
#
# [2713 rows x 3 columns]

# %%
stck["% Change"]=stck["FINOLEXIND.BO"].div(stck.lag1).sub(1).mul(100)

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff  % Change
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.088027
# 2010-01-06      56.500000   56.849998 -0.349998 -0.615653
# 2010-01-07      57.000000   56.500000  0.500000  0.884956
# 2010-01-08      61.750000   57.000000  4.750000  8.333333
# ...                   ...         ...       ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.158210
# 2020-12-28     128.830002  122.889999  5.940002  4.833593
# 2020-12-29     128.990005  128.830002  0.160004  0.124198
# 2020-12-30     129.289993  128.990005  0.299988  0.232567
# 2020-12-31     129.300003  129.289993  0.010010  0.007742
#
# [2713 rows x 4 columns]

# %%
stck["Diff2"]= stck["FINOLEXIND.BO"].diff(periods=1)
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.088027  0.049999
# 2010-01-06      56.500000   56.849998 -0.349998 -0.615653 -0.349998
# 2010-01-07      57.000000   56.500000  0.500000  0.884956  0.500000
# 2010-01-08      61.750000   57.000000  4.750000  8.333333  4.750000
# ...                   ...         ...       ...       ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.158210 -1.440002
# 2020-12-28     128.830002  122.889999  5.940002  4.833593  5.940002
# 2020-12-29     128.990005  128.830002  0.160004  0.124198  0.160004
# 2020-12-30     129.289993  128.990005  0.299988  0.232567  0.299988
# 2020-12-31     129.300003  129.289993  0.010010  0.007742  0.010010
#
# [2713 rows x 5 columns]

# %%
stck["% Change 2"]=stck["FINOLEXIND.BO"].pct_change(periods=1).mul(100)

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff  % Change     Diff2  \
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.088027  0.049999
# 2010-01-06      56.500000   56.849998 -0.349998 -0.615653 -0.349998
# 2010-01-07      57.000000   56.500000  0.500000  0.884956  0.500000
# 2010-01-08      61.750000   57.000000  4.750000  8.333333  4.750000
# ...                   ...         ...       ...       ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.158210 -1.440002
# 2020-12-28     128.830002  122.889999  5.940002  4.833593  5.940002
# 2020-12-29     128.990005  128.830002  0.160004  0.124198  0.160004
# 2020-12-30     129.289993  128.990005  0.299988  0.232567  0.299988
# 2020-12-31     129.300003  129.289993  0.010010  0.007742  0.010010
#
#             % Change 2
# Date
# 2010-01-04         NaN
# 2010-01-05    0.088027
# 2010-01-06   -0.615653
# 2010-01-07    0.884956
# 2010-01-08    8.333333
# ...                ...
# 2020-12-24   -1.158210
# 2020-12-28    4.833593
# 2020-12-29    0.124198
# 2020-12-30    0.232567
# 2020-12-31    0.007742
#
# [2713 rows x 6 columns]

# %%
del stck["% Change"]

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff     Diff2  % Change 2
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN         NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.049999    0.088027
# 2010-01-06      56.500000   56.849998 -0.349998 -0.349998   -0.615653
# 2010-01-07      57.000000   56.500000  0.500000  0.500000    0.884956
# 2010-01-08      61.750000   57.000000  4.750000  4.750000    8.333333
# ...                   ...         ...       ...       ...         ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.440002   -1.158210
# 2020-12-28     128.830002  122.889999  5.940002  5.940002    4.833593
# 2020-12-29     128.990005  128.830002  0.160004  0.160004    0.124198
# 2020-12-30     129.289993  128.990005  0.299988  0.299988    0.232567
# 2020-12-31     129.300003  129.289993  0.010010  0.010010    0.007742
#
# [2713 rows x 5 columns]

# %%
stck.rename(columns = {'% Change 2':'Change'}, inplace = True)

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff     Diff2    Change
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.049999  0.088027
# 2010-01-06      56.500000   56.849998 -0.349998 -0.349998 -0.615653
# 2010-01-07      57.000000   56.500000  0.500000  0.500000  0.884956
# 2010-01-08      61.750000   57.000000  4.750000  4.750000  8.333333
# ...                   ...         ...       ...       ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.440002 -1.158210
# 2020-12-28     128.830002  122.889999  5.940002  5.940002  4.833593
# 2020-12-29     128.990005  128.830002  0.160004  0.160004  0.124198
# 2020-12-30     129.289993  128.990005  0.299988  0.299988  0.232567
# 2020-12-31     129.300003  129.289993  0.010010  0.010010  0.007742
#
# [2713 rows x 5 columns]

# %%
stck["FINOLEXIND.BO"].resample("M").last()
# Out:
# Date
# 2010-01-31     57.200001
# 2010-02-28     53.150002
# 2010-03-31     65.199997
# 2010-04-30     80.650002
# 2010-05-31     70.699997
#                  ...
# 2020-08-31    101.080002
# 2020-09-30    100.480003
# 2020-10-31    104.680000
# 2020-11-30    125.980003
# 2020-12-31    129.300003
# Freq: M, Name: FINOLEXIND.BO, Length: 132, dtype: float64

# %%
stck["FINOLEXIND.BO"].resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26    -7.080418
# 2010-03-31    22.671675
# 2010-04-30    23.696327
# 2010-05-31   -12.337265
#                 ...
# 2020-08-31     9.393940
# 2020-09-30    -0.593588
# 2020-10-30     4.179933
# 2020-11-30    20.347729
# 2020-12-31     2.635339
# Freq: BM, Name: FINOLEXIND.BO, Length: 132, dtype: float64

# %%
stck
# Out:
#             FINOLEXIND.BO        lag1      Diff     Diff2    Change
# Date
# 2010-01-04      56.799999         NaN       NaN       NaN       NaN
# 2010-01-05      56.849998   56.799999  0.049999  0.049999  0.088027
# 2010-01-06      56.500000   56.849998 -0.349998 -0.349998 -0.615653
# 2010-01-07      57.000000   56.500000  0.500000  0.500000  0.884956
# 2010-01-08      61.750000   57.000000  4.750000  4.750000  8.333333
# ...                   ...         ...       ...       ...       ...
# 2020-12-24     122.889999  124.330002 -1.440002 -1.440002 -1.158210
# 2020-12-28     128.830002  122.889999  5.940002  5.940002  4.833593
# 2020-12-29     128.990005  128.830002  0.160004  0.160004  0.124198
# 2020-12-30     129.289993  128.990005  0.299988  0.299988  0.232567
# 2020-12-31     129.300003  129.289993  0.010010  0.010010  0.007742
#
# [2713 rows x 5 columns]

# %%
del stck["Change"]
del stck["Diff2"]
del stck["Diff"]
del stck["lag1"]

# %%
stck
# Out:
#             FINOLEXIND.BO
# Date
# 2010-01-04      56.799999
# 2010-01-05      56.849998
# 2010-01-06      56.500000
# 2010-01-07      57.000000
# 2010-01-08      61.750000
# ...                   ...
# 2020-12-24     122.889999
# 2020-12-28     128.830002
# 2020-12-29     128.990005
# 2020-12-30     129.289993
# 2020-12-31     129.300003
#
# [2713 rows x 1 columns]

# %%
ret = stck.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2712 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FINOLEXIND.BO  2712 non-null   float64
# dtypes: float64(1)
# memory usage: 42.4 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# FINOLEXIND.BO    0.000882
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# FINOLEXIND.BO    0.000779
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# FINOLEXIND.BO    0.027903
# dtype: float64

# %%
ret.std()
# Out:
# FINOLEXIND.BO    0.027903
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# FINOLEXIND.BO    0.222231
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# FINOLEXIND.BO    0.196206
# dtype: float64

# %%
annual_std_retuens=np.sqrt(annual_var_return)

# %%
annual_std_retuens
# Out:
# FINOLEXIND.BO    0.442951
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# FINOLEXIND.BO    0.442951
# dtype: float64

# %%
ticker=["FINOLEXIND.BO", "IBULHSGFIN.NS", "BANKBARODA.NS"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2022-12-30")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#             BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# Date
# 2013-07-24      -0.048287      -0.018093      -0.049956
# 2013-07-25      -0.012282      -0.000768      -0.050000
# 2013-07-26      -0.013807       0.003842      -0.049913
# 2013-07-29      -0.017652      -0.004210      -0.049877
# 2013-07-30      -0.018677      -0.014220      -0.049914

# %%
ret.describe().T
# Out:
#                 count      mean       std       min       25%       50%  \
# BANKBARODA.NS  2326.0  0.000562  0.028118 -0.163771 -0.014208  0.000000
# FINOLEXIND.BO  2326.0  0.000755  0.027528 -0.809571 -0.010245 -0.000322
# IBULHSGFIN.NS  2326.0  0.000397  0.035953 -0.344014 -0.015772 -0.000505
#
#                     75%       max
# BANKBARODA.NS  0.014838  0.314356
# FINOLEXIND.BO  0.010241  0.143074
# IBULHSGFIN.NS  0.015127  0.310989

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#                    mean       std
# BANKBARODA.NS  0.000562  0.028118
# FINOLEXIND.BO  0.000755  0.027528
# IBULHSGFIN.NS  0.000397  0.035953

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#                    mean       std
# BANKBARODA.NS  0.141740  0.446358
# FINOLEXIND.BO  0.190182  0.436988
# IBULHSGFIN.NS  0.099991  0.570733

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual return",fontsize = 15)
plt.title("Risk/return",fontsize=25)
plt.show()

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#             BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# Date
# 2013-07-24      -0.048287      -0.018093      -0.049956
# 2013-07-25      -0.012282      -0.000768      -0.050000
# 2013-07-26      -0.013807       0.003842      -0.049913
# 2013-07-29      -0.017652      -0.004210      -0.049877
# 2013-07-30      -0.018677      -0.014220      -0.049914
# ...                   ...            ...            ...
# 2022-12-23      -0.042752      -0.074444      -0.090181
# 2022-12-26       0.047619       0.086134       0.074244
# 2022-12-27       0.002823       0.026803       0.060563
# 2022-12-28       0.023649      -0.011841      -0.010077
# 2022-12-29       0.019527       0.031046       0.058025
#
# [2326 rows x 3 columns]

# %%
ret.cov()
# Out:
#                BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# BANKBARODA.NS       0.000791       0.000182       0.000345
# FINOLEXIND.BO       0.000182       0.000758       0.000216
# IBULHSGFIN.NS       0.000345       0.000216       0.001293

# %%
ret.corr()
# Out:
#                BANKBARODA.NS  FINOLEXIND.BO  IBULHSGFIN.NS
# BANKBARODA.NS       1.000000       0.235013       0.341623
# FINOLEXIND.BO       0.235013       1.000000       0.218147
# IBULHSGFIN.NS       0.341623       0.218147       1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %% [markdown]
# ## Challenge 1
# ### Download 20 random stocks and
# ### 1. Calcualte risk and reward potential
# ### 2. Compare the covariance and coorelation
# ### 3. Find the best 5 to invest in long term

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
#Mean returns are misleading as crazy

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("FINOLEXIND.BO")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 2000-01-03   34.000000
# 2000-01-04   35.250000
# 2000-01-05   32.450001
# 2000-01-06   32.250000
# 2000-01-07   30.100000
# ...                ...
# 2022-12-23  166.600006
# 2022-12-26  180.949997
# 2022-12-27  185.800003
# 2022-12-28  183.600006
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#             Close
# Date
# 2000-01-03    NaN
# 2000-01-04    NaN
# 2000-01-05    NaN
# 2000-01-06    NaN
# 2000-01-07    NaN
# 2000-01-10    NaN
# 2000-01-11    NaN
# 2000-01-12    NaN
# 2000-01-13    NaN
# 2000-01-14  32.10
# 2000-01-17  31.66
# 2000-01-18  31.11
# 2000-01-19  30.85
# 2000-01-20  30.62
# 2000-01-21  30.71

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 2000-01-03         NaN
# 2000-01-04         NaN
# 2000-01-05         NaN
# 2000-01-06         NaN
# 2000-01-07         NaN
# ...                ...
# 2022-12-23  179.525002
# 2022-12-26  180.099998
# 2022-12-27  180.574997
# 2022-12-28  181.650002
# 2022-12-29  181.650002
#
# [5690 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 2000-01-03         NaN
# 2000-01-04         NaN
# 2000-01-05         NaN
# 2000-01-06         NaN
# 2000-01-07         NaN
# ...                ...
# 2022-12-23  186.000000
# 2022-12-26  186.000000
# 2022-12-27  186.000000
# 2022-12-28  186.000000
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max()
# Out:
#                  Close
# Date
# 2000-01-03         NaN
# 2000-01-04         NaN
# 2000-01-05         NaN
# 2000-01-06         NaN
# 2000-01-07   35.250000
# ...                ...
# 2022-12-23  186.000000
# 2022-12-26  186.000000
# 2022-12-27  186.000000
# 2022-12-28  186.000000
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
spy
# Out:
#                  Close
# Date
# 2000-01-03   34.000000
# 2000-01-04   35.250000
# 2000-01-05   32.450001
# 2000-01-06   32.250000
# 2000-01-07   30.100000
# ...                ...
# 2022-12-23  166.600006
# 2022-12-26  180.949997
# 2022-12-27  185.800003
# 2022-12-28  183.600006
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 2000-01-03   34.000000         NaN
# 2000-01-04   35.250000         NaN
# 2000-01-05   32.450001         NaN
# 2000-01-06   32.250000         NaN
# 2000-01-07   30.100000         NaN
# ...                ...         ...
# 2022-12-23  166.600006  156.148999
# 2022-12-26  180.949997  157.048999
# 2022-12-27  185.800003  158.004999
# 2022-12-28  183.600006  158.930999
# 2022-12-29  189.300003  159.963000
#
# [5690 rows x 2 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 2000-01-03   34.000000         NaN         NaN
# 2000-01-04   35.250000         NaN         NaN
# 2000-01-05   32.450001         NaN         NaN
# 2000-01-06   32.250000         NaN         NaN
# 2000-01-07   30.100000         NaN         NaN
# ...                ...         ...         ...
# 2022-12-23  166.600006  156.148999  148.860249
# 2022-12-26  180.949997  157.048999  149.031499
# 2022-12-27  185.800003  158.004999  149.223999
# 2022-12-28  183.600006  158.930999  149.374999
# 2022-12-29  189.300003  159.963000  149.536749
#
# [5690 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %% [markdown]
# ## Challenge 2
# ### Take the 5 stocks that you picked and plot the moving averages and graph it

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 2000-01-03   34.000000         NaN         NaN         NaN
# 2000-01-04   35.250000         NaN         NaN         NaN
# 2000-01-05   32.450001         NaN         NaN         NaN
# 2000-01-06   32.250000         NaN         NaN         NaN
# 2000-01-07   30.100000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2022-12-23  166.600006  156.148999  148.860249  154.905156
# 2022-12-26  180.949997  157.048999  149.031499  155.420896
# 2022-12-27  185.800003  158.004999  149.223999  156.022462
# 2022-12-28  183.600006  158.930999  149.374999  156.568552
# 2022-12-29  189.300003  159.963000  149.536749  157.216700
#
# [5690 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy["Quarter"]=spy.index.quarter

# %%
SPY = yf.download("FINOLEXIND.BO")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
all_days=pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 2000-01-03   34.000000
# 2000-01-04   35.250000
# 2000-01-05   32.450001
# 2000-01-06   32.250000
# 2000-01-07   30.100000
# ...                ...
# 2022-12-23  166.600006
# 2022-12-26  180.949997
# 2022-12-27  185.800003
# 2022-12-28  183.600006
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31   97.400002
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  102.050003
# 2011-01-04   98.650002
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  543.900024
# 2019-12-31  545.750000
# 2020-01-01  538.599976
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="ffill")
# Out:
#                  Close
# 2010-12-31   97.400002
# 2011-01-01   97.400002
# 2011-01-02   97.400002
# 2011-01-03  102.050003
# 2011-01-04   98.650002
# ...                ...
# 2019-12-28  544.450012
# 2019-12-29  544.450012
# 2019-12-30  543.900024
# 2019-12-31  545.750000
# 2020-01-01  538.599976
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method="bfill")
# Out:
#                  Close
# 2010-12-31   97.400002
# 2011-01-01  102.050003
# 2011-01-02  102.050003
# 2011-01-03  102.050003
# 2011-01-04   98.650002
# ...                ...
# 2019-12-28  543.900024
# 2019-12-29  543.900024
# 2019-12-30  543.900024
# 2019-12-31  545.750000
# 2020-01-01  538.599976
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("FINOLEXIND.BO",interval="1wk")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   35.500000   36.000000   30.000000   30.100000   25.393536
# 2000-01-10   32.099998   34.000000   29.750000   30.500000   25.730989
# 2000-01-17   31.000000   31.799999   29.000000   31.000000   26.152805
# 2000-01-24   32.000000   32.799999   28.750000   31.000000   26.152805
# 2000-01-31   30.750000   31.000000   28.250000   29.000000   24.465525
# ...                ...         ...         ...         ...         ...
# 2022-11-28  158.649994  163.899994  153.500000  163.399994  163.399994
# 2022-12-05  163.550003  181.449997  163.550003  171.800003  171.800003
# 2022-12-12  172.050003  187.600006  166.000000  182.350006  182.350006
# 2022-12-19  182.350006  190.949997  164.000000  166.600006  166.600006
# 2022-12-26  167.000000  194.949997  167.000000  189.300003  189.300003
#
#              Volume
# Date
# 2000-01-03   730763
# 2000-01-10   235830
# 2000-01-17   222567
# 2000-01-24   372650
# 2000-01-31   503810
# ...             ...
# 2022-11-28   476846
# 2022-12-05  2006854
# 2022-12-12  1375427
# 2022-12-19  1447720
# 2022-12-26   852482
#
# [1196 rows x 6 columns]

# %% [markdown]
# ## Cummaltive Returns, Drawdowns etc..

# %%
stock=yf.download("FINOLEXIND.BO")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock=stock.Close.to_frame()

# %%
stock
# Out:
#                  Close
# Date
# 2000-01-03   34.000000
# 2000-01-04   35.250000
# 2000-01-05   32.450001
# 2000-01-06   32.250000
# 2000-01-07   30.100000
# ...                ...
# 2022-12-23  166.600006
# 2022-12-26  180.949997
# 2022-12-27  185.800003
# 2022-12-28  183.600006
# 2022-12-29  189.300003
#
# [5690 rows x 1 columns]

# %%
stock["d_returns"]=np.log(stock.div(stock.shift(1)))

# %%
stock
# Out:
#                  Close  d_returns
# Date
# 2000-01-03   34.000000        NaN
# 2000-01-04   35.250000   0.036105
# 2000-01-05   32.450001  -0.082765
# 2000-01-06   32.250000  -0.006182
# 2000-01-07   30.100000  -0.068993
# ...                ...        ...
# 2022-12-23  166.600006  -0.077361
# 2022-12-26  180.949997   0.082625
# 2022-12-27  185.800003   0.026450
# 2022-12-28  183.600006  -0.011911
# 2022-12-29  189.300003   0.030574
#
# [5690 rows x 2 columns]

# %%
stock.dropna(inplace=True)

# %%
stock
# Out:
#                  Close  d_returns
# Date
# 2000-01-04   35.250000   0.036105
# 2000-01-05   32.450001  -0.082765
# 2000-01-06   32.250000  -0.006182
# 2000-01-07   30.100000  -0.068993
# 2000-01-10   32.450001   0.075175
# ...                ...        ...
# 2022-12-23  166.600006  -0.077361
# 2022-12-26  180.949997   0.082625
# 2022-12-27  185.800003   0.026450
# 2022-12-28  183.600006  -0.011911
# 2022-12-29  189.300003   0.030574
#
# [5689 rows x 2 columns]

# %%
stock.d_returns.sum()
# Out:
# 1.7169725497203898

# %%
np.exp(stock.d_returns.sum())
# Out:
# 5.567647148581094

# %%
stock["cummreturns"]=stock.d_returns.cumsum().apply(np.exp)

# %%
stock
# Out:
#                  Close  d_returns  cummreturns
# Date
# 2000-01-04   35.250000   0.036105     1.036765
# 2000-01-05   32.450001  -0.082765     0.954412
# 2000-01-06   32.250000  -0.006182     0.948529
# 2000-01-07   30.100000  -0.068993     0.885294
# 2000-01-10   32.450001   0.075175     0.954412
# ...                ...        ...          ...
# 2022-12-23  166.600006  -0.077361     4.900000
# 2022-12-26  180.949997   0.082625     5.322059
# 2022-12-27  185.800003   0.026450     5.464706
# 2022-12-28  183.600006  -0.011911     5.400000
# 2022-12-29  189.300003   0.030574     5.567647
#
# [5689 rows x 3 columns]

# %%
stock.cummreturns.plot(figsize=(12,8),title="stock buy and hold", fontsize=12)
plt.show()

# %%
stock.d_returns.mean()*252
# Out:
# 0.07605503296353282

# %%
stock.d_returns.std()*np.sqrt(252)
# Out:
# 0.539301590088406

# %%
# how to calculate drawdowns
stock["cummmax"]=stock.cummreturns.cummax()

# %%
stock
# Out:
#                  Close  d_returns  cummreturns    cummmax
# Date
# 2000-01-04   35.250000   0.036105     1.036765   1.036765
# 2000-01-05   32.450001  -0.082765     0.954412   1.036765
# 2000-01-06   32.250000  -0.006182     0.948529   1.036765
# 2000-01-07   30.100000  -0.068993     0.885294   1.036765
# 2000-01-10   32.450001   0.075175     0.954412   1.036765
# ...                ...        ...          ...        ...
# 2022-12-23  166.600006  -0.077361     4.900000  21.611764
# 2022-12-26  180.949997   0.082625     5.322059  21.611764
# 2022-12-27  185.800003   0.026450     5.464706  21.611764
# 2022-12-28  183.600006  -0.011911     5.400000  21.611764
# 2022-12-29  189.300003   0.030574     5.567647  21.611764
#
# [5689 rows x 4 columns]

# %%
stock[["cummreturns","cummmax"]].plot(figsize=(12,8),title="stock buy and hold+cummmax", fontsize=12)
plt.show()

# %%
stock["drawdown"]=stock["cummmax"]-stock["cummreturns"]

# %%
stock
# Out:
#                  Close  d_returns  cummreturns    cummmax   drawdown
# Date
# 2000-01-04   35.250000   0.036105     1.036765   1.036765   0.000000
# 2000-01-05   32.450001  -0.082765     0.954412   1.036765   0.082353
# 2000-01-06   32.250000  -0.006182     0.948529   1.036765   0.088235
# 2000-01-07   30.100000  -0.068993     0.885294   1.036765   0.151471
# 2000-01-10   32.450001   0.075175     0.954412   1.036765   0.082353
# ...                ...        ...          ...        ...        ...
# 2022-12-23  166.600006  -0.077361     4.900000  21.611764  16.711764
# 2022-12-26  180.949997   0.082625     5.322059  21.611764  16.289706
# 2022-12-27  185.800003   0.026450     5.464706  21.611764  16.147058
# 2022-12-28  183.600006  -0.011911     5.400000  21.611764  16.211764
# 2022-12-29  189.300003   0.030574     5.567647  21.611764  16.044117
#
# [5689 rows x 5 columns]

# %%
stock.drawdown.max()
# Out:
# 19.495587966021436

# %%
stock.drawdown.idxmax()
# Out:
# Timestamp('2020-05-11 00:00:00')

# %%
stock.loc[(stock.index<='2020-09-18')]
# Out:
#                  Close  d_returns  cummreturns    cummmax   drawdown
# Date
# 2000-01-04   35.250000   0.036105     1.036765   1.036765   0.000000
# 2000-01-05   32.450001  -0.082765     0.954412   1.036765   0.082353
# 2000-01-06   32.250000  -0.006182     0.948529   1.036765   0.088235
# 2000-01-07   30.100000  -0.068993     0.885294   1.036765   0.151471
# 2000-01-10   32.450001   0.075175     0.954412   1.036765   0.082353
# ...                ...        ...          ...        ...        ...
# 2020-09-14  108.900002   0.074617     3.202941  21.611764  18.408823
# 2020-09-15  107.120003  -0.016480     3.150588  21.611764  18.461176
# 2020-09-16  106.269997  -0.007967     3.125588  21.611764  18.486176
# 2020-09-17  107.000000   0.006846     3.147059  21.611764  18.464706
# 2020-09-18  108.489998   0.013829     3.190882  21.611764  18.420882
#
# [5123 rows x 5 columns]

# %%
stock["drawdown%"]=(stock["cummmax"]-stock["cummreturns"])/stock["cummmax"]

# %%
stock
# Out:
#                  Close  d_returns  cummreturns    cummmax   drawdown  \
# Date
# 2000-01-04   35.250000   0.036105     1.036765   1.036765   0.000000
# 2000-01-05   32.450001  -0.082765     0.954412   1.036765   0.082353
# 2000-01-06   32.250000  -0.006182     0.948529   1.036765   0.088235
# 2000-01-07   30.100000  -0.068993     0.885294   1.036765   0.151471
# 2000-01-10   32.450001   0.075175     0.954412   1.036765   0.082353
# ...                ...        ...          ...        ...        ...
# 2022-12-23  166.600006  -0.077361     4.900000  21.611764  16.711764
# 2022-12-26  180.949997   0.082625     5.322059  21.611764  16.289706
# 2022-12-27  185.800003   0.026450     5.464706  21.611764  16.147058
# 2022-12-28  183.600006  -0.011911     5.400000  21.611764  16.211764
# 2022-12-29  189.300003   0.030574     5.567647  21.611764  16.044117
#
#             drawdown%
# Date
# 2000-01-04   0.000000
# 2000-01-05   0.079433
# 2000-01-06   0.085106
# 2000-01-07   0.146099
# 2000-01-10   0.079433
# ...               ...
# 2022-12-23   0.773272
# 2022-12-26   0.753743
# 2022-12-27   0.747142
# 2022-12-28   0.750136
# 2022-12-29   0.742379
#
# [5689 rows x 6 columns]

# %%
stock["drawdown%"].max()
# Out:
# 0.9020822017643881

# %%
stock["drawdown%"].idxmax()
# Out:
# Timestamp('2020-05-11 00:00:00')

# %%
stock.loc[(stock.index<='2020-03-31')]
# Out:
#                  Close  d_returns  cummreturns    cummmax   drawdown  \
# Date
# 2000-01-04   35.250000   0.036105     1.036765   1.036765   0.000000
# 2000-01-05   32.450001  -0.082765     0.954412   1.036765   0.082353
# 2000-01-06   32.250000  -0.006182     0.948529   1.036765   0.088235
# 2000-01-07   30.100000  -0.068993     0.885294   1.036765   0.151471
# 2000-01-10   32.450001   0.075175     0.954412   1.036765   0.082353
# ...                ...        ...          ...        ...        ...
# 2020-03-25  321.049988   0.051777     9.442647  21.611764  12.169118
# 2020-03-26  350.950012   0.089047    10.322059  21.611764  11.289705
# 2020-03-27  377.600006   0.073192    11.105883  21.611764  10.505882
# 2020-03-30  359.299988  -0.049678    10.567647  21.611764  11.044118
# 2020-03-31  390.700012   0.083782    11.491177  21.611764  10.120588
#
#             drawdown%
# Date
# 2000-01-04   0.000000
# 2000-01-05   0.079433
# 2000-01-06   0.085106
# 2000-01-07   0.146099
# 2000-01-10   0.079433
# ...               ...
# 2020-03-25   0.563078
# 2020-03-26   0.522387
# 2020-03-27   0.486119
# 2020-03-30   0.511023
# 2020-03-31   0.468291
#
# [5006 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
data=stock.Close.loc[(stock.index>='1992-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 2000-01-04   35.250000
# 2000-01-05   32.450001
# 2000-01-06   32.250000
# 2000-01-07   30.100000
# 2000-01-10   32.450001
# ...                ...
# 2022-12-23  166.600006
# 2022-12-26  180.949997
# 2022-12-27  185.800003
# 2022-12-28  183.600006
# 2022-12-29  189.300003
#
# [5689 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 2000-01-04   35.250000         NaN         NaN
# 2000-01-05   32.450001         NaN         NaN
# 2000-01-06   32.250000         NaN         NaN
# 2000-01-07   30.100000         NaN         NaN
# 2000-01-10   32.450001         NaN         NaN
# ...                ...         ...         ...
# 2022-12-23  166.600006  156.148999  149.667500
# 2022-12-26  180.949997  157.048999  150.148999
# 2022-12-27  185.800003  158.004999  150.645999
# 2022-12-28  183.600006  158.930999  151.092500
# 2022-12-29  189.300003  159.963000  151.611500
#
# [5689 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title="FINOLEX IND. - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <AxesSubplot: title={'center': 'FINOLEX IND. - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="FINOLEX IND. - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <AxesSubplot: title={'center': 'FINOLEX IND. - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 2000-06-09   18.750000   21.906000   25.416000
# 2000-06-12   19.100000   21.831000   25.254500
# 2000-06-13   19.049999   21.753000   25.120500
# 2000-06-14   19.000000   21.682000   24.988000
# 2000-06-15   19.250000   21.631000   24.879500
# ...                ...         ...         ...
# 2022-12-23  166.600006  156.148999  149.667500
# 2022-12-26  180.949997  157.048999  150.148999
# 2022-12-27  185.800003  158.004999  150.645999
# 2022-12-28  183.600006  158.930999  151.092500
# 2022-12-29  189.300003  159.963000  151.611500
#
# [5590 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 2000-06-09   18.750000   21.906000   25.416000        -1
# 2000-06-12   19.100000   21.831000   25.254500        -1
# 2000-06-13   19.049999   21.753000   25.120500        -1
# 2000-06-14   19.000000   21.682000   24.988000        -1
# 2000-06-15   19.250000   21.631000   24.879500        -1
# ...                ...         ...         ...       ...
# 2022-12-23  166.600006  156.148999  149.667500         1
# 2022-12-26  180.949997  157.048999  150.148999         1
# 2022-12-27  185.800003  158.004999  150.645999         1
# 2022-12-28  183.600006  158.930999  151.092500         1
# 2022-12-29  189.300003  159.963000  151.611500         1
#
# [5590 rows x 4 columns]

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="FINOLEX IND. - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <AxesSubplot: title={'center': 'FINOLEX IND. - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 2000-06-09   18.750000   21.906000   25.416000        -1         NaN       NaN
# 2000-06-12   19.100000   21.831000   25.254500        -1    0.018495 -0.018495
# 2000-06-13   19.049999   21.753000   25.120500        -1   -0.002621  0.002621
# 2000-06-14   19.000000   21.682000   24.988000        -1   -0.002628  0.002628
# 2000-06-15   19.250000   21.631000   24.879500        -1    0.013072 -0.013072
# ...                ...         ...         ...       ...         ...       ...
# 2022-12-23  166.600006  156.148999  149.667500         1   -0.077361 -0.077361
# 2022-12-26  180.949997  157.048999  150.148999         1    0.082625  0.082625
# 2022-12-27  185.800003  158.004999  150.645999         1    0.026450  0.026450
# 2022-12-28  183.600006  158.930999  151.092500         1   -0.011911 -0.011911
# 2022-12-29  189.300003  159.963000  151.611500         1    0.030574  0.030574
#
# [5590 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    2.312139
# strategy      2.373042
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    10.096000
# strategy      10.729988
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252) #annyal std
# Out:
# returnsb&h    0.536113
# strategy      0.536111
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    2.293645
# strategy2     2.342591
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h     9.910995
# strategy2     10.408168
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.536147
# strategy2     0.299295
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.536144
# strategy2    0.299295
# dtype: float64

# %% [markdown]
# ## Find the best SMA for the top 5 stocks
# ## Create a bias strategy
# ## Compare drawdowns
# ## Pick the best 3 stocks for your portfolio

# %% [markdown]
# # Creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std= data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("BANKBARODA.NS","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (0.3216665053666501, 0.44506562849007725)

# %% [markdown]
# ## Creating our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std= data["strategy"].std()*np.sqrt(252)
    
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester= SMABacktester("BANKBARODA.NS",50,100, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (0.060381, -10.873096)

# %%
tester.plot_results()

# %% [markdown]
# ## 1. Watch Stan Weinstein Stratgey in our QuantProgram Youtube channel
# ## 2. Create the stratgey in python
# ## 3. Backtest it
# ## 4. Save it as a class in a separate python file.
