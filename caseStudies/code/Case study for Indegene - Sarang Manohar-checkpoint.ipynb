# %% [markdown]
# <a href="https://colab.research.google.com/github/sarang-manohar/hogwarts/blob/main/caseStudies/code/Case%20study%20for%20Indegene%20-%20Sarang%20Manohar-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Code to connect to repo

# %%
key = \
'''
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
'''
 
# !cat /root/.ssh/id_rsa
 
print('\n')
 
# !mkdir -p /root/.ssh
with open(r'/root/.ssh/id_rsa', 'w', encoding='utf8') as fh:
    fh.write(key)
# !ssh-keyscan github.com >> /root/.ssh/known_hosts   #additional steps added on 6/14/2021: Sarang
# !chmod 644 /root/.ssh/known_hosts                   #additional steps added on 6/14/2021: Sarang
# !chmod 600 /root/.ssh/id_rsa
# !ssh -T git@github.com
# !git clone git@github.com:sarang-manohar/hogwarts.git
# Out:
# -----BEGIN RSA PRIVATE KEY-----
# MIIJKQIBAAKCAgEA6OysIjD9z+ok/UbOS8lA4dnNaZSUGZF/bx887CHohfotnzzF
# 74nF+tSuNWXvkEtjYtd5Km8wGNt9aTs4T5MCLj927jGTIXq9xSSIABa3GnuT9W1k
# 9TTzsSWQqpwiOPEc7KY0hGxRCEK7cWVZbmkzPvW7hpj+tmuQDDticEWCyE9IKvvg
# U0qAyg9m0Bv8cywy2XfWfR8ozHs4vbL/dtW/LmSC7K3OwnBXwg/yEZZkw7acO5Hh
# hbx6tlKBGNPHHyNtU9+PumPZceOENKGFN+GiM2Ktv5IEgkPAtwtn0lZFO1Am5/Nb
# ZxWWhxtyYsgKUXQtpOh5m3xNhaBz/aNlN9MaflfQr4JIeJP7AZafMT/MVVqFAbbv
# njpGyqKxDPrLPKr1dgwU2nY2WieypBZkkXKgcuotY+yhCfvyzj+MH8lMek0pNDsp
# QY6I1TOf2wJ51bLmCwSWqcbwXhGCQcbaAzJSnYdyq5rKwG0pYm+PMq9ql/b3IooF
# qyyFqVnd77UaAYIGysCdxhEQ2fw6cp2jcI6DiFM1XoupyGU/WbVAuVsqQ55CHlx8
# JK9qOHXcrSrCErKzv7wsSF1oJIYDgZREotGO+H9sw5Ng9QNz/XuR4yZ/l1YZDI8J
# 54ZWvFvBgXrvmgFDiZME/BknHTUdirKOrmes1cKVCvJuJA7vKhaKALrgUmcCAwEA
# AQKCAgEAk1eLuAFHvWs/RNyyiSxhF72AfEZZvSbV9wRKtJDqlz3f+DgoedOsYnSB
# UxQNjDi0QQVPB3HYehD2b0ff4i57lafd4uWHTgln3Dq0sWGtKFp+CSXPVHHPqgK6
# VcJ4v45+npCw7gfa5p/YFO5ouThhC3XEz2sezWSTdblnFuBRz8afP1mf2PBrMea2
# ...

# %% [markdown]
# ## Background
# 1. The Customer Data tab contains the data for your assignment
# 2. The data is at a customer level (doctor data) and contains the following information:
#     * Customer Demographic information
#     * Promotional activity targeted at the customer (emails, calls, faxes).
#     * Calls refers to the tele-marketing calls made to doctors (columns H and I); Emails refers to promotional emails (columns J & K) and Faxes refers to promotional material faxed to doctors (col L)
#     * Sales data by the customer (Brand 1, Brand 2, Branded Market and Total Market)
#
# 3. Brand 1 is pharma Company's brand for which promotional activity has been performed
# 4. Brand 2 is a key competitor of Brand 1
# 5. Total Branded Market contains sales of Brand 1, Brand 2 and some other brands
# 6. Total Market (Branded + Unbranded) Sales contains sales of Total Branded Market and Unbranded Market products
#
# ### Business Problem
# 1. Using Exploratory Data Analysis, show your understanding of the Brand and Market situation
# 2. Build a predictive model that estimates the impact of each channel (i.e. Calls, Emails, Faxes) on Brand 1 sales, for different customer segments based on total market sales(Column P)
# 3. Consider columns C to M for building predictive model, considering column M as your target variable

# %%
# !pip install category_encoders

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics
import statsmodels.tools as sm
from statsmodels.regression.linear_model import OLS

import warnings
warnings.filterwarnings('ignore')

import category_encoders as ce

# %%
#rd = pd.read_csv('../data/prescription_prediction.csv',sep='\t'); rd.head()

# %%
rd = pd.read_csv('/content/hogwarts/caseStudies/data/prescription_prediction.csv',sep='\t'); rd.head()
# Out:
#   Customer ID  ... Total Market (Branded + Unbranded) Sales
# 0   IND000001  ...                                      131
# 1   IND000002  ...                                       56
# 2   IND000003  ...                                      161
# 3   IND000004  ...                                      180
# 4   IND000005  ...                                       44
#
# [5 rows x 15 columns]

# %%
rd.shape
# Out:
# (77641, 15)

# %%
rd.tail()
# Out:
#       Customer ID  ... Total Market (Branded + Unbranded) Sales
# 77636   IND077637  ...                                       94
# 77637   IND077638  ...                                       43
# 77638   IND077639  ...                                        4
# 77639   IND077640  ...                                       61
# 77640   IND077641  ...                                       93
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Preliminary EDA

# %%
rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77641 entries, 0 to 77640
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Customer ID                               77641 non-null  object
#  1   Title                                     77641 non-null  object
#  2   Specialty Code                            77641 non-null  object
#  3   Specialty Description                     77641 non-null  object
#  4   State                                     77641 non-null  object
#  5   Region                                    76280 non-null  object
#  6   Call Attempts                             77641 non-null  int64
#  7   Calls Successfully Completed              77641 non-null  int64
#  8   Emails Sent                               77641 non-null  int64
#  9   Emails Opened                             77641 non-null  int64
# ...

# %%
print(rd['Region'].isnull().sum()*100/77641)
print(rd["Brand 1 Sales (Company's Brand)"].isnull().sum()*100/77641)
print(rd['Brand 2 Sales (Competitor Brand)'].isnull().sum()*100/77641)
# Out:
# 1.7529398127278113
# 0.06697492304323746
# 56.40705297458817

# %%
rd[rd.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Title, Specialty Code, Specialty Description, State, Region, Call Attempts, Calls Successfully Completed, Emails Sent, Emails Opened, Faxes Sent, Brand 1 Sales (Company's Brand), Brand 2 Sales (Competitor Brand), Total Branded Market Sales, Total Market (Branded + Unbranded) Sales]
# Index: []

# %%
rd.columns = ['cust_id', 'title', 'spec_code', 'spec_desc','st', 'reg', 'atmptd_calls', 'calls_cmpltd','emails_snt', 'emails_opnd', 'faxes_snt','brnd_sls', 'comp_sls','tot_brnded_sls','tot_mkt_sls']

# %%
rd.head(1)
# Out:
#      cust_id title spec_code  ... comp_sls tot_brnded_sls tot_mkt_sls
# 0  IND000001    MD        FM  ...      NaN             27         131
#
# [1 rows x 15 columns]

# %%
# check if calls completed are greater than attempted calls
rd[np.where(rd['calls_cmpltd']>rd['atmptd_calls'],True,False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, title, spec_code, spec_desc, st, reg, atmptd_calls, calls_cmpltd, emails_snt, emails_opnd, faxes_snt, brnd_sls, comp_sls, tot_brnded_sls, tot_mkt_sls]
# Index: []

# %%
# check if emails opened are greater than emails sent, this is with the assumption that if same email is opened multiple times it would treated as one open
rd[np.where(rd['emails_opnd']>rd['emails_snt'],True,False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, title, spec_code, spec_desc, st, reg, atmptd_calls, calls_cmpltd, emails_snt, emails_opnd, faxes_snt, brnd_sls, comp_sls, tot_brnded_sls, tot_mkt_sls]
# Index: []

# %%
# check if brand sales is greater than total branded sales
rd[np.where(rd['brnd_sls']>rd['tot_brnded_sls'],True,False)]
# Out:
# Empty DataFrame
# Columns: [cust_id, title, spec_code, spec_desc, st, reg, atmptd_calls, calls_cmpltd, emails_snt, emails_opnd, faxes_snt, brnd_sls, comp_sls, tot_brnded_sls, tot_mkt_sls]
# Index: []

# %%
# check if total branded sales is greater than total market sales which includes both branded and unbranded sales
print(rd[np.where(rd['tot_brnded_sls']>rd['tot_mkt_sls'],True,False)].shape[0]*100/77641)
# Out:
# 29.900439200937647

# %% [markdown]
# ## Detailed EDA

# %%
rd_cat = rd[[ 'title', 'spec_code', 'spec_desc','st', 'reg']]

# %%
rd_cont = rd[['atmptd_calls', 'calls_cmpltd','emails_snt', 'emails_opnd', 'faxes_snt','brnd_sls', 'comp_sls','tot_brnded_sls','tot_mkt_sls']]

# %%
for col in rd_cat.columns: 
    print('{} has {} unique values. The count for each value is as below.'.format(col,rd_cat[col].nunique()))
    print(rd_cat[col].value_counts(),'\n\n')
# Out:
# title has 56 unique values. The count for each value is as below.
# MD     58798
# DO      9014
# NP      2792
# PA      2142
# PAC     1371
# FNP     1151
# APR      751
# MSN      469
# NPC      138
# CRN      130
# APN      123
# CNP      118
# ANP      117
# ARN      113
# DNP       72
# RPA       60
# MPA       56
# MS        38
# CFN       25
# BC        21
# MSP       19
# MMS       14
# PHD        7
# MN         7
# NUR        6
# DDS        6
# GNP        6
# DPM        5
# RN         5
# AGN        5
# BS         4
# CNS        4
# DVM        4
# MPH        4
# NPF        4
# OD         4
# RNP        3
# CNM        3
# NPB        3
# ND         3
# AGA        3
# PHA        3
# BCF        2
# PRA        2
# AGP        2
# DMD        2
# PC         2
# NMD        2
# RNB        1
# VMD        1
# MNF        1
# PMH        1
# MBA        1
# PAN        1
# CS         1
# BSM        1
# Name: title, dtype: int64
#
#
# ...

# %%
rd_cont.skew()
# Out:
# atmptd_calls       0.001477
# calls_cmpltd       0.762738
# emails_snt         0.003836
# emails_opnd        0.554297
# faxes_snt         -0.004659
# brnd_sls           6.007734
# comp_sls          31.526980
# tot_brnded_sls     0.310270
# tot_mkt_sls        5.022796
# dtype: float64

# %%
from scipy.stats import shapiro as shapiro

for feature in rd_cont.columns:
    stats, p_val = shapiro(rd_cont[feature])
    print('Normality test for', feature)
    print('Statitics = %.3f, p value = %.3f' % (stats, p_val))
    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    sns.kdeplot(ax=axes[0], x=rd_cont[feature])
    sns.boxplot(ax=axes[1], y=rd_cont[feature])
    plt.show()
    if p_val > 0.05: print(feature, 'is normally distribution and has Gaussian curve.\n')
    else: print(feature, 'is not normally distributed.\n')
# Out:
# Normality test for atmptd_calls
# Statitics = 0.906, p value = 0.000
# atmptd_calls is not normally distributed.
#
# Normality test for calls_cmpltd
# Statitics = 0.833, p value = 0.000
# calls_cmpltd is not normally distributed.
#
# Normality test for emails_snt
# Statitics = 0.951, p value = 0.000
# emails_snt is not normally distributed.
#
# Normality test for emails_opnd
# Statitics = 0.894, p value = 0.000
# emails_opnd is not normally distributed.
#
# Normality test for faxes_snt
# Statitics = 0.935, p value = 0.000
# faxes_snt is not normally distributed.
#
# Normality test for brnd_sls
# Statitics = nan, p value = 1.000
# brnd_sls is normally distribution and has Gaussian curve.
#
# Normality test for comp_sls
# Statitics = nan, p value = 1.000
# comp_sls is normally distribution and has Gaussian curve.
#
# Normality test for tot_brnded_sls
# Statitics = 0.962, p value = 0.000
# tot_brnded_sls is not normally distributed.
#
# Normality test for tot_mkt_sls
# ...

# %%
rd_cont['brnd_sls'].median()
# Out:
# 5.0

# %%
df = rd.copy()

# %%
df['brnd_sls'].fillna(5, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77641 entries, 0 to 77640
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cust_id         77641 non-null  object
#  1   title           77641 non-null  object
#  2   spec_code       77641 non-null  object
#  3   spec_desc       77641 non-null  object
#  4   st              77641 non-null  object
#  5   reg             76280 non-null  object
#  6   atmptd_calls    77641 non-null  int64
#  7   calls_cmpltd    77641 non-null  int64
#  8   emails_snt      77641 non-null  int64
#  9   emails_opnd     77641 non-null  int64
#  10  faxes_snt       77641 non-null  int64
#  11  brnd_sls        77641 non-null  float64
#  12  comp_sls        33846 non-null  float64
#  13  tot_brnded_sls  77641 non-null  int64
#  14  tot_mkt_sls     77641 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 8.9+ MB

# %% [markdown]
# Specialty code has 137 distinct nominal values. It would need some sort of encoding before we can proceed with and model building.

# %%
df_cont = df[['atmptd_calls', 'calls_cmpltd','emails_snt', 'emails_opnd', 'faxes_snt','brnd_sls', 'comp_sls','tot_brnded_sls','tot_mkt_sls']]

# %%
outlier = []
for x in rd_cont:
    q1, q3 = np.percentile(df_cont[x],[25,75])
    iqr = q3 - q1
    lower_bound = q1 -(1.5 * iqr) 
    upper_bound = q3 +(1.5 * iqr)
    for y in df_cont[x]:
        if y<lower_bound:
            outlier.append(df_cont[x])
        elif y>upper_bound:
            outlier.append(df_cont[x])
    #print(outlier)
    print('Percent of outliers for ',x,'is',len(outlier)*100/77641)
# Out:
# Percent of outliers for  atmptd_calls is 0.0
# Percent of outliers for  calls_cmpltd is 0.0
# Percent of outliers for  emails_snt is 0.0
# Percent of outliers for  emails_opnd is 0.0
# Percent of outliers for  faxes_snt is 0.0
# Percent of outliers for  brnd_sls is 2.0375832356615704
# Percent of outliers for  comp_sls is 2.0375832356615704
# Percent of outliers for  tot_brnded_sls is 2.095542303679757
# Percent of outliers for  tot_mkt_sls is 9.30178642727425

# %%
np.percentile(df_cont['brnd_sls'],[25,75])
# Out:
# array([3., 6.])

# %%
df[df['reg'].isnull()]['st'].unique()
# Out:
# array(['PR', 'DC', 'AP', 'AE', 'VI'], dtype=object)

# %%
df['reg'].replace(to_replace=np.nan,value='US Territory', inplace=True)

# %%
df['reg'].unique()
# Out:
# array(['South Region', 'Northeast Region', 'Midwest Region',
#        'West Region', 'US Territory'], dtype=object)

# %%
df['comp_sls'].replace(to_replace=np.nan,value=0, inplace=True)

# %% [markdown]
# ### Checkpoint

# %%
tot_mkt_sls_new = []
for x in range(0,len(df['tot_mkt_sls'])):
    if df['tot_mkt_sls'].iloc[x]>=df['tot_brnded_sls'].iloc[x]:
        tot_mkt_sls_new.append(df['tot_mkt_sls'].iloc[x])
    else:
        tot_mkt_sls_new.append(df['tot_brnded_sls'].iloc[x])
print(tot_mkt_sls_new)
# Out:
# [131, 56, 161, 180, 44, 36, 298, 31, 217, 227, 43, 151, 33, 42, 255, 31, 19, 27, 247, 201, 49, 45, 28, 160, 18, 380, 72, 58, 173, 21, 25, 36, 163, 53, 143, 28, 247, 125, 78, 367, 45, 208, 146, 111, 376, 31, 39, 286, 22, 56, 279, 269, 50, 47, 43, 70, 55, 80, 43, 27, 83, 145, 823, 309, 93, 101, 49, 122, 40, 97, 282, 96, 62, 54, 111, 130, 55, 46, 43, 40, 66, 65, 66, 48, 160, 250, 59, 36, 49, 123, 78, 42, 143, 65, 63, 51, 157, 57, 53, 61, 31, 131, 173, 90, 44, 29, 60, 272, 62, 54, 33, 25, 45, 25, 33, 29, 80, 62, 43, 226, 57, 42, 50, 5, 255, 54, 108, 53, 18, 38, 76, 32, 95, 258, 234, 54, 12, 38, 43, 48, 182, 46, 40, 47, 45, 52, 74, 104, 50, 96, 9, 40, 35, 60, 58, 424, 95, 105, 36, 137, 39, 86, 139, 229, 59, 57, 221, 96, 68, 27, 109, 360, 58, 34, 139, 96, 33, 909, 51, 54, 42, 38, 53, 105, 36, 28, 161, 76, 38, 74, 139, 65, 49, 25, 66, 28, 240, 98, 115, 43, 88, 224, 39, 183, 131, 49, 92, 261, 118, 251, 41, 54, 105, 294, 4, 39, 80, 205, 406, 27, 1155, 110, 73, 117, 17, 22, 27, 94, 31, 78, 111
# ...

# %%
df['tot_mkt_sls_new'] = tot_mkt_sls_new

# %%
# check if total branded sales is greater than total market sales which includes both branded and unbranded sales
print(df[np.where(df['tot_brnded_sls']>df['tot_mkt_sls'],True,False)].shape[0]*100/77641)
# Out:
# 29.900439200937647

# %%
# check if total branded sales is greater than total market sales which includes both branded and unbranded sales
print(df[np.where(df['tot_brnded_sls']>df['tot_mkt_sls_new'],True,False)].shape[0]*100/77641)
# Out:
# 0.0

# %%
#spec_grp = pd.read_csv('../data/spec_grp_lkp.csv',sep='\t'); spec_grp.head()

# %%
spec_grp = pd.read_csv('/content/hogwarts/caseStudies/data/spec_grp_lkp.csv',sep='\t'); spec_grp.head()
# Out:
#   spec_code           spec_grp
# 0         A     ALLERGY/IMMUNO
# 1       ADL         PEDIATRICS
# 2       ADM              OTHER
# 3       ADP         PSYCHIATRY
# 4       AHF  INTERNAL MEDICINE

# %%
df_v2 = pd.merge(df, spec_grp, on='spec_code')

# %%
df_v2['tot_comp_sls'] = df_v2['tot_brnded_sls'] - df_v2['brnd_sls']

# %%
df_v2.head()
# Out:
#      cust_id title spec_code  ... tot_mkt_sls_new          spec_grp tot_comp_sls
# 0  IND000001    MD        FM  ...             131  FAMILY/GEN. PRAC         19.0
# 1  IND000004    MD        FM  ...             180  FAMILY/GEN. PRAC         30.0
# 2  IND000008    MD        FM  ...              31  FAMILY/GEN. PRAC         28.0
# 3  IND000009    MD        FM  ...             217  FAMILY/GEN. PRAC         27.0
# 4  IND000011    MD        FM  ...              43  FAMILY/GEN. PRAC         41.0
#
# [5 rows x 18 columns]

# %%
df_v3 = df_v2.copy()

# %%
df_v3.drop({'cust_id','title','spec_code','spec_desc','st','comp_sls','tot_mkt_sls'},axis=1,inplace=True); df_v3.head()
# Out:
#             reg  atmptd_calls  ...          spec_grp  tot_comp_sls
# 0  South Region             1  ...  FAMILY/GEN. PRAC          19.0
# 1  South Region             0  ...  FAMILY/GEN. PRAC          30.0
# 2  South Region             2  ...  FAMILY/GEN. PRAC          28.0
# 3  South Region             4  ...  FAMILY/GEN. PRAC          27.0
# 4  South Region             4  ...  FAMILY/GEN. PRAC          41.0
#
# [5 rows x 11 columns]

# %%
df_v3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77641 entries, 0 to 77640
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reg              77641 non-null  object
#  1   atmptd_calls     77641 non-null  int64
#  2   calls_cmpltd     77641 non-null  int64
#  3   emails_snt       77641 non-null  int64
#  4   emails_opnd      77641 non-null  int64
#  5   faxes_snt        77641 non-null  int64
#  6   brnd_sls         77641 non-null  float64
#  7   tot_brnded_sls   77641 non-null  int64
#  8   tot_mkt_sls_new  77641 non-null  int64
#  9   spec_grp         77641 non-null  object
#  10  tot_comp_sls     77641 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 7.1+ MB

# %%
# Memory saving function credit to https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.
    """
    start_mem = df.memory_usage().sum() / 1024**2
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                #if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                #    df[col] = df[col].astype(np.float16)
                #el
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        #else:
            #df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB --> {:.2f} MB (Decreased by {:.1f}%)'.format(
        start_mem, end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_final = reduce_mem_usage(df_v3)
# Out:
# Memory usage of dataframe is 7.11 MB --> 3.04 MB (Decreased by 57.3%)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77641 entries, 0 to 77640
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reg              77641 non-null  object
#  1   atmptd_calls     77641 non-null  int8
#  2   calls_cmpltd     77641 non-null  int8
#  3   emails_snt       77641 non-null  int8
#  4   emails_opnd      77641 non-null  int8
#  5   faxes_snt        77641 non-null  int8
#  6   brnd_sls         77641 non-null  float32
#  7   tot_brnded_sls   77641 non-null  int16
#  8   tot_mkt_sls_new  77641 non-null  int16
#  9   spec_grp         77641 non-null  object
#  10  tot_comp_sls     77641 non-null  float32
# dtypes: float32(2), int16(2), int8(5), object(2)
# memory usage: 3.0+ MB

# %%
df_final.shape
# Out:
# (77641, 11)

# %%
df_final.columns
# Out:
# Index(['reg', 'atmptd_calls', 'calls_cmpltd', 'emails_snt', 'emails_opnd',
#        'faxes_snt', 'brnd_sls', 'tot_brnded_sls', 'tot_mkt_sls_new',
#        'spec_grp', 'tot_comp_sls'],
#       dtype='object')

# %% [markdown]
# ### Brand Analysis

# %%
sns.set_palette("mako")
sns.set_style("whitegrid")

# %%
df_reg_brnd = df_final.groupby(['reg'])[['reg','brnd_sls']].sum().reset_index().sort_values(['brnd_sls'],ascending=False).reset_index().drop({'index'},axis=1)
fig = plt.figure(figsize=(10,5))
sns.barplot(data=df_reg_brnd,x='reg',y='brnd_sls',ci=False,estimator=sum)
plt.title('Brand Sales by Region'); plt.xlabel('Region'); plt.ylabel('Brand Sales'); plt.yticks([0,40000,80000,120000,160000],['0','40K','80K','120K','140K']); plt.show()
df_reg_brnd['share'] = (df_reg_brnd['brnd_sls']/df_reg_brnd['brnd_sls'].sum())
df_reg_brnd.columns = ['Region','Brand Sales','Percent Share']
df_reg_brnd.index = df_reg_brnd['Region']
display(df_reg_brnd.round(4).drop('Region',axis=1).T)
# Out:
# Region         South Region  Midwest Region  ...   West Region  US Territory
# Brand Sales     136251.0000      95463.0000  ...  58542.003906     6889.0000
# Percent Share        0.3679          0.2578  ...      0.158100        0.0186
#
# [2 rows x 5 columns]

# %%
df_spec_grp_brnd = df_final.groupby(['spec_grp'])[['spec_grp','brnd_sls']].sum().reset_index().sort_values(['brnd_sls'],ascending=False).reset_index().drop({'index'},axis=1)
fig = plt.figure(figsize=(5,8))
sns.barplot(data=df_spec_grp_brnd.iloc[0:10,],y='spec_grp',x='brnd_sls',ci=False,estimator=sum)
plt.title('Brand Sales by Specialty Groups'); plt.xlabel('Brand Sales'); plt.ylabel('Specialty Groups'); plt.xticks([0,40000,80000,120000,160000],['0','40K','80K','120K','140K']); plt.show()
df_spec_grp_brnd['share'] = (df_spec_grp_brnd['brnd_sls']/df_spec_grp_brnd['brnd_sls'].sum())
df_spec_grp_brnd.columns = ['Specialty Groups','Brand Sales','Percent Share']
display(df_spec_grp_brnd.iloc[0:10,].round(4))
# Out:
#         Specialty Groups  Brand Sales  Percent Share
# 0       FAMILY/GEN. PRAC     148755.0         0.4016
# 1      INTERNAL MEDICINE     119569.0         0.3228
# 2                UNKNOWN      51981.0         0.1404
# 3             CARDIOLOGY      30036.0         0.0811
# 4         ENDO/DIAB/META       9395.0         0.0254
# 5             GERIATRICS       2975.0         0.0080
# 6     EMERGENCY MEDICINE       1376.0         0.0037
# 7             PEDIATRICS        989.0         0.0027
# 8  OBSTETRICS/GYNECOLOGY        830.0         0.0022
# 9                SURGERY        823.0         0.0022

# %% [markdown]
# ### Market Analysis

# %%
df_reg_mkt = df_final.groupby(['reg'])[['reg','tot_mkt_sls_new']].sum().reset_index().sort_values(['tot_mkt_sls_new'],ascending=False).reset_index().drop({'index'},axis=1)
fig = plt.figure(figsize=(10,5))
sns.barplot(data=df_reg_mkt,x='reg',y='tot_mkt_sls_new',ci=False,estimator=sum)
plt.title('Market Sales by Region'); plt.xlabel('Region'); plt.ylabel('Market Sales');
plt.yticks([0,500000,1000000,1500000,2000000,2500000],['0','0.5M','1M','1.5M','2M','2.5M']); plt.show()
df_reg_mkt['share'] = (df_reg_mkt['tot_mkt_sls_new']/df_reg_mkt['tot_mkt_sls_new'].sum())
df_reg_mkt.columns = ['Region','Market Sales','Percent Share']
df_reg_mkt.index = df_reg_mkt['Region']
display(df_reg_mkt.drop('Region',axis=1))
# Out:
#                   Market Sales  Percent Share
# Region
# South Region         2720537.0       0.418689
# Midwest Region       1426905.0       0.219600
# Northeast Region     1148580.0       0.176766
# West Region          1033612.0       0.159072
# US Territory          168123.0       0.025874

# %%
df_spec_grp_mkt = df_final.groupby(['spec_grp'])[['spec_grp','tot_mkt_sls_new']].sum().reset_index().sort_values(['tot_mkt_sls_new'],ascending=False).reset_index().drop({'index'},axis=1)
fig = plt.figure(figsize=(5,8))
sns.barplot(data=df_spec_grp_mkt.iloc[0:10,],y='spec_grp',x='tot_mkt_sls_new',ci=False,estimator=sum)
plt.title('Market Sales by Specialty Groups'); plt.xlabel('Market Sales'); plt.ylabel('Specialty Groups'); 
plt.xticks([0,500000,1000000,1500000,2000000,2500000],['0','0.5M','1M','1.5M','2M','2.5M']); plt.show()
df_spec_grp_mkt['share'] = (df_spec_grp_mkt['tot_mkt_sls_new']/df_spec_grp_mkt['tot_mkt_sls_new'].sum())
df_spec_grp_mkt.columns = ['Specialty Groups','Market Sales','Percent Share']
display(df_spec_grp_mkt.iloc[0:10,].round(4))
# Out:
#      Specialty Groups  Market Sales  Percent Share
# 0    FAMILY/GEN. PRAC     2760689.0         0.4249
# 1   INTERNAL MEDICINE     2172828.0         0.3344
# 2             UNKNOWN      777850.0         0.1197
# 3          CARDIOLOGY      449198.0         0.0691
# 4      ENDO/DIAB/META      171638.0         0.0264
# 5          GERIATRICS       50590.0         0.0078
# 6  EMERGENCY MEDICINE       23726.0         0.0037
# 7          PEDIATRICS       16978.0         0.0026
# 8             SURGERY       14562.0         0.0022
# 9               OTHER       11690.0         0.0018

# %%
df_final.columns
# Out:
# Index(['reg', 'atmptd_calls', 'calls_cmpltd', 'emails_snt', 'emails_opnd',
#        'faxes_snt', 'brnd_sls', 'tot_brnded_sls', 'tot_mkt_sls_new',
#        'spec_grp', 'tot_comp_sls'],
#       dtype='object')

# %%
plt.style.use('seaborn')

# %%
#sns.pairplot(data=df_final,kind='reg')

# %%
g1 = sns.pairplot(df_final[['brnd_sls','atmptd_calls', 'calls_cmpltd']], diag_kind="kde")

# %%
g2 = sns.pairplot(df_final[['brnd_sls','emails_snt', 'emails_opnd','faxes_snt']], diag_kind="kde")

# %%
g3 = sns.pairplot(df_final[['brnd_sls','tot_comp_sls', 'tot_brnded_sls','tot_mkt_sls_new']], diag_kind="kde")

# %%
df_final[['brnd_sls','tot_comp_sls', 'tot_brnded_sls','tot_mkt_sls_new']].corr(method='pearson').round(2)
# Out:
#                  brnd_sls  tot_comp_sls  tot_brnded_sls  tot_mkt_sls_new
# brnd_sls             1.00          0.01            0.18             0.34
# tot_comp_sls         0.01          1.00            0.98             0.07
# tot_brnded_sls       0.18          0.98            1.00             0.13
# tot_mkt_sls_new      0.34          0.07            0.13             1.00

# %%
sns.jointplot(data=df_final,x='brnd_sls',y='atmptd_calls',kind='kde')

# %%
sns.jointplot(data=df_final,x='brnd_sls',y='faxes_snt')

# %%
spec_grp_encoder= ce.BaseNEncoder(cols=['spec_grp'],return_df=True,base=7)
df_spec_grp_endcoded = spec_grp_encoder.fit_transform(df_final)
df_spec_grp_endcoded.sample(5)
# Out:
#                     reg  atmptd_calls  ...  spec_grp_2  tot_comp_sls
# 75584  Northeast Region             3  ...           3          22.0
# 43038    Midwest Region             1  ...           3          27.0
# 69690      South Region             1  ...           3          28.0
# 42663      South Region             0  ...           3          41.0
# 20935      South Region             5  ...           1          29.0
#
# [5 rows x 13 columns]

# %%
reg_encoder= ce.BaseNEncoder(cols=['reg'],return_df=True,base=3)
df_endcoded = reg_encoder.fit_transform(df_spec_grp_endcoded)
df_endcoded.sample(5)
# Out:
#        reg_0  reg_1  reg_2  ...  spec_grp_1  spec_grp_2  tot_comp_sls
# 24763      0      1      1  ...           0           1          29.0
# 57585      0      0      2  ...           0           4          19.0
# 46400      0      0      1  ...           0           3          46.0
# 37236      0      1      0  ...           0           3          26.0
# 12516      0      1      1  ...           0           1          16.0
#
# [5 rows x 15 columns]

# %%
df_endcoded = reduce_mem_usage(df_endcoded)
# Out:
# Memory usage of dataframe is 5.41 MB --> 2.30 MB (Decreased by 57.5%)

# %%
df_endcoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77641 entries, 0 to 77640
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reg_0            77641 non-null  int8
#  1   reg_1            77641 non-null  int8
#  2   reg_2            77641 non-null  int8
#  3   atmptd_calls     77641 non-null  int8
#  4   calls_cmpltd     77641 non-null  int8
#  5   emails_snt       77641 non-null  int8
#  6   emails_opnd      77641 non-null  int8
#  7   faxes_snt        77641 non-null  int8
#  8   brnd_sls         77641 non-null  float32
#  9   tot_brnded_sls   77641 non-null  int16
#  10  tot_mkt_sls_new  77641 non-null  int16
#  11  spec_grp_0       77641 non-null  int8
#  12  spec_grp_1       77641 non-null  int8
#  13  spec_grp_2       77641 non-null  int8
#  14  tot_comp_sls     77641 non-null  float32
# dtypes: float32(2), int16(2), int8(11)
# memory usage: 2.3 MB

# %%
q1, q3 = np.percentile(df_endcoded['tot_mkt_sls_new'],[33,67])

# %%
df_lv = df_endcoded[df_endcoded['tot_mkt_sls_new']<=q1]
df_lv.sample(5)
# Out:
#        reg_0  reg_1  reg_2  ...  spec_grp_1  spec_grp_2  tot_comp_sls
# 31946      0      0      1  ...           0           2           5.0
# 28522      0      0      1  ...           0           2          13.0
# 66506      0      1      1  ...           1           3          15.0
# 31962      0      0      1  ...           0           2           9.0
# 59409      0      0      1  ...           0           2          26.0
#
# [5 rows x 15 columns]

# %%
df_mv = df_endcoded[df_endcoded['tot_mkt_sls_new'].between(q1, q3, inclusive = False)]
df_mv.sample(5)
# Out:
#        reg_0  reg_1  reg_2  ...  spec_grp_1  spec_grp_2  tot_comp_sls
# 71157      0      1      1  ...           1           3          18.0
# 30164      0      1      0  ...           0           2          46.0
# 4062       0      0      1  ...           0           1           8.0
# 18306      0      0      2  ...           0           1          10.0
# 422        0      1      0  ...           0           1          13.0
#
# [5 rows x 15 columns]

# %%
df_hv = df_endcoded[df_endcoded['tot_mkt_sls_new']>=q3]
df_hv.sample(5)
# Out:
#        reg_0  reg_1  reg_2  ...  spec_grp_1  spec_grp_2  tot_comp_sls
# 63661      0      0      2  ...           1           3          14.0
# 73161      0      0      2  ...           0           1          35.0
# 57754      0      1      1  ...           0           4          22.0
# 25396      0      0      2  ...           0           1          19.0
# 10240      0      0      2  ...           0           1          38.0
#
# [5 rows x 15 columns]

# %%
print(df_lv.shape[0]+df_mv.shape[0]+df_hv.shape[0],df_lv.shape[0],df_mv.shape[0],df_hv.shape[0])
# Out:
# 77641 26845 24958 25838

# %% [markdown]
# # Trying models with encoded region and specialty group variables

# %%
df_model = df_endcoded.copy()

# %%
df_model.columns
# Out:
# Index(['reg_0', 'reg_1', 'reg_2', 'atmptd_calls', 'calls_cmpltd', 'emails_snt',
#        'emails_opnd', 'faxes_snt', 'brnd_sls', 'tot_brnded_sls',
#        'tot_mkt_sls_new', 'spec_grp_0', 'spec_grp_1', 'spec_grp_2',
#        'tot_comp_sls'],
#       dtype='object')

# %%
X = df_model.drop({'brnd_sls','tot_brnded_sls','tot_mkt_sls_new','tot_comp_sls'}, axis=1, inplace=False)
y = df_model.pop('brnd_sls')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

importances = pd.DataFrame(dt.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(dt.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
dt.score(X_train,y_train)
# Out:
# 0.9545059192297961

# %%
dt.score(X_test,y_test)
# Out:
# -0.32105764537548365

# %%
ytrain_predict = dt.predict(X_train)
ytest_predict = dt.predict(X_test)

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_train, ytrain_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_train, ytrain_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_train, ytrain_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_train, ytrain_predict))
print('Max Error:', metrics.max_error(y_train, ytrain_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_train, ytrain_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_train, ytrain_predict))
print('R^2:', metrics.r2_score(y_train, ytrain_predict))
# Out:
# Mean Absolute Error (MAE): 0.16806186318771874
# Mean Squared Error (MSE): 0.3189524405576514
# Root Mean Squared Error (RMSE): 0.5647587454459216
# Explained Variance Score: 0.9545059214364663
# Max Error: 16.0
# Mean Squared Log Error: 0.012700962237185238
# Median Absolute Error: 0.0
# R^2: 0.9545059192297961

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, ytest_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, ytest_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_test, ytest_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_test, ytest_predict))
print('Max Error:', metrics.max_error(y_test, ytest_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_test, ytest_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, ytest_predict))
print('R^2:', metrics.r2_score(y_test, ytest_predict))
# Out:
# Mean Absolute Error (MAE): 1.4207327292073781
# Mean Squared Error (MSE): 9.822518481418815
# Root Mean Squared Error (RMSE): 3.134089737295155
# Explained Variance Score: -0.31978700387975634
# Max Error: 63.0
# Mean Squared Log Error: 0.11953958922875763
# Median Absolute Error: 1.0
# R^2: -0.32105764537548365

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

importances = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
rf.score(X_train,y_train)
# Out:
# 0.8793099722296465

# %%
rf.score(X_test,y_test)
# Out:
# 0.3073422776724247

# %%
ytrain_predict = rf.predict(X_train)
ytest_predict = rf.predict(X_test)

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_train, ytrain_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_train, ytrain_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_train, ytrain_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_train, ytrain_predict))
print('Max Error:', metrics.max_error(y_train, ytrain_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_train, ytrain_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_train, ytrain_predict))
print('R^2:', metrics.r2_score(y_train, ytrain_predict))
# Out:
# Mean Absolute Error (MAE): 0.515210269543462
# Mean Squared Error (MSE): 0.8461403825865783
# Root Mean Squared Error (RMSE): 0.9198588927583287
# Explained Variance Score: 0.8794774840908197
# Max Error: 26.808
# Mean Squared Log Error: 0.01985786805172808
# Median Absolute Error: 0.31000000000000005
# R^2: 0.8793099722296465

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, ytest_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, ytest_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_test, ytest_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_test, ytest_predict))
print('Max Error:', metrics.max_error(y_test, ytest_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_test, ytest_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, ytest_predict))
print('R^2:', metrics.r2_score(y_test, ytest_predict))
# Out:
# Mean Absolute Error (MAE): 1.2169502420214358
# Mean Squared Error (MSE): 5.150148672676787
# Root Mean Squared Error (RMSE): 2.269393899850087
# Explained Variance Score: 0.3082874879054158
# Max Error: 62.85
# Mean Squared Log Error: 0.08001912601396069
# Median Absolute Error: 0.7833333333333341
# R^2: 0.3073422776724247

# %%
import statsmodels.tools as sm
import statsmodels.regression.linear_model as lm

x_train = sm.add_constant(X_train)

sm_lr = lm.OLS(y_train, x_train).fit()

print(sm_lr.summary())

print('RMSE --- >',np.sqrt(sm_lr.mse_resid))
print('AIC ---- >',sm_lr.aic)
print('Adj R-sq >',sm_lr.rsquared_adj,'\n\n')

sk_lr = LinearRegression()
sk_lr.fit(X_train,y_train)
y_train_pred = sk_lr.predict(X_train)
print('R-sqr    >',sk_lr.score(X_train, y_train))
print('RMSEtrain>',metrics.mean_squared_error(y_train, y_train_pred, squared=False))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               brnd_sls   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     3604.
# Date:                Fri, 02 Jul 2021   Prob (F-statistic):               0.00
# Time:                        05:18:31   Log-Likelihood:            -1.1732e+05
# No. Observations:               54348   AIC:                         2.347e+05
# Df Residuals:                   54338   BIC:                         2.347e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.0067      0.042     47.682      0.000       1.924       2.089
# ...

# %%
sk_lr.score(X_train,y_train)
# Out:
# 0.37377247154130266

# %%
sk_lr.score(X_test,y_test)
# Out:
# 0.366291181014215

# %%
ytrain_predict = sk_lr.predict(X_train)
ytest_predict = sk_lr.predict(X_test)

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_train, ytrain_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_train, ytrain_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_train, ytrain_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_train, ytrain_predict))
print('Max Error:', metrics.max_error(y_train, ytrain_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_train, ytrain_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_train, ytrain_predict))
print('R^2:', metrics.r2_score(y_train, ytrain_predict))
# Out:
# Mean Absolute Error (MAE): 1.2857602103549153
# Mean Squared Error (MSE): 4.390390907229942
# Root Mean Squared Error (RMSE): 2.095325966819946
# Explained Variance Score: 0.3737725019161898
# Max Error: 61.80482006181656
# Mean Squared Log Error: 0.08770758155920003
# Median Absolute Error: 1.0016992892361984
# R^2: 0.37377247154130266

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, ytest_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, ytest_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_test, ytest_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_test, ytest_predict))
print('Max Error:', metrics.max_error(y_test, ytest_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_test, ytest_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, ytest_predict))
print('R^2:', metrics.r2_score(y_test, ytest_predict))
# Out:
# Mean Absolute Error (MAE): 1.2870607403529546
# Mean Squared Error (MSE): 4.711843278085524
# Root Mean Squared Error (RMSE): 2.170678068734635
# Explained Variance Score: 0.36631640573104673
# Max Error: 63.80422071021759
# Mean Squared Log Error: 0.08715084983595846
# Median Absolute Error: 0.9919293702887364
# R^2: 0.366291181014215

# %%
sns.scatterplot(x=y_train,y=ytrain_predict); plt.xlabel('Training labels'); plt.ylabel('Predictions'); plt.show()

# %%
sns.scatterplot(x=y_test,y=ytest_predict); plt.xlabel('Test labels'); plt.ylabel('Predictions'); plt.show()

# %% [markdown]
# # Random forest optimization

# %%
df_model = df_endcoded.copy()

# %%
X = df_model.drop({'brnd_sls','tot_brnded_sls','tot_mkt_sls_new','tot_comp_sls'}, axis=1, inplace=False)
y = df_model.pop('brnd_sls')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth' : [6,8,10,12],
    'min_samples_leaf' : [50,100,200,500],
    'min_samples_split' : [100,300,600,900],
    'max_features' : [3],
    'n_estimators' : [100,200,300]
}

# %%
rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid, cv = 3)
rf_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %%
best_rf = rf_gs.best_estimator_
ytrain_predict = best_rf.predict(X_train)
ytest_predict = best_rf.predict(X_test)

# %%
importances = pd.DataFrame(best_rf.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(best_rf.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
importances
# Out:
#          Imp      features    cumsum
# 0   0.469795   emails_opnd  0.469795
# 1   0.225381  calls_cmpltd  0.695176
# 2   0.125956    emails_snt  0.821131
# 3   0.097851     faxes_snt  0.918982
# 4   0.046540  atmptd_calls  0.965522
# 5   0.022625         reg_2  0.988148
# 6   0.004820    spec_grp_2  0.992968
# 7   0.004445         reg_1  0.997412
# 8   0.002588    spec_grp_1  1.000000
# 9   0.000000         reg_0  1.000000
# 10  0.000000    spec_grp_0  1.000000

# %%
import joblib
joblib.dump(best_rf, "./random_forest.joblib")
# Out:
# ['./random_forest.joblib']

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_train, ytrain_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_train, ytrain_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_train, ytrain_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_train, ytrain_predict))
print('Max Error:', metrics.max_error(y_train, ytrain_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_train, ytrain_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_train, ytrain_predict))
print('R^2:', metrics.r2_score(y_train, ytrain_predict))
# Out:
# Mean Absolute Error (MAE): 1.1149197666210746
# Mean Squared Error (MSE): 3.8307055885803756
# Root Mean Squared Error (RMSE): 1.9572188402374364
# Explained Variance Score: 0.4536037471532024
# Max Error: 61.3895705464332
# Mean Squared Log Error: 0.06646045603727427
# Median Absolute Error: 0.8102705985392007
# R^2: 0.4536037123621055

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, ytest_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, ytest_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_test, ytest_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_test, ytest_predict))
print('Max Error:', metrics.max_error(y_test, ytest_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_test, ytest_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, ytest_predict))
print('R^2:', metrics.r2_score(y_test, ytest_predict))
# Out:
# Mean Absolute Error (MAE): 1.1464978129913799
# Mean Squared Error (MSE): 4.331165886619205
# Root Mean Squared Error (RMSE): 2.0811453304897296
# Explained Variance Score: 0.4175113743551644
# Max Error: 63.17165771362765
# Mean Squared Log Error: 0.06916103097558736
# Median Absolute Error: 0.825359855541203
# R^2: 0.4174895350177735

# %%
sns.scatterplot(x=y_train,y=ytrain_predict); plt.xlabel('Training labels'); plt.ylabel('Predictions'); plt.show()

# %%
sns.scatterplot(x=y_test,y=ytest_predict); plt.xlabel('Test labels'); plt.ylabel('Predictions'); plt.show()

# %%
best_rf.score(X_train,y_train)
# Out:
# 0.45360371236210545

# %%
best_rf.score(X_test,y_test)
# Out:
# 0.4174895350177736

# %%
sk_lr.score(X_train,y_train)
# Out:
# 0.37377247154130266

# %%
sk_lr.score(X_test,y_test)
# Out:
# 0.366291181014215

# %%
rf.score(X_train,y_train)
# Out:
# 0.8770898172959473

# %%
rf.score(X_test,y_test)
# Out:
# 0.3088474450018779

# %% [markdown]
# # Dropping encoded region and Specialty group variables for the model

# %%
df_model = df_endcoded.copy()
df_model.columns
# Out:
# Index(['reg_0', 'reg_1', 'reg_2', 'atmptd_calls', 'calls_cmpltd', 'emails_snt',
#        'emails_opnd', 'faxes_snt', 'brnd_sls', 'tot_brnded_sls',
#        'tot_mkt_sls_new', 'spec_grp_0', 'spec_grp_1', 'spec_grp_2',
#        'tot_comp_sls'],
#       dtype='object')

# %%
X = df_model[['atmptd_calls', 'calls_cmpltd', 'emails_snt','emails_opnd', 'faxes_snt']]
y = df_model[['brnd_sls']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

importances = pd.DataFrame(dt.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(dt.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

importances = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(rf.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
dt.score(X_train,y_train)
# Out:
# 0.7358497324267746

# %%
rf.score(X_train,y_train)
# Out:
# 0.7073251780753614

# %%
import statsmodels.tools as sm
import statsmodels.regression.linear_model as lm

x_train = sm.add_constant(X_train)

sm_lr = lm.OLS(y_train, x_train).fit()

print(sm_lr.summary())

print('RMSE --- >',np.sqrt(sm_lr.mse_resid))
print('AIC ---- >',sm_lr.aic)
print('Adj R-sq >',sm_lr.rsquared_adj,'\n\n')

sk_lr = LinearRegression()
sk_lr.fit(X_train,y_train)
y_train_pred = sk_lr.predict(X_train)
print('R-sqr    >',sk_lr.score(X_train, y_train))
print('RMSEtrain>',metrics.mean_squared_error(y_train, y_train_pred, squared=False))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               brnd_sls   R-squared:                       0.360
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     6119.
# Date:                Thu, 01 Jul 2021   Prob (F-statistic):               0.00
# Time:                        15:19:15   Log-Likelihood:            -1.1790e+05
# No. Observations:               54348   AIC:                         2.358e+05
# Df Residuals:                   54342   BIC:                         2.359e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.3813      0.029     81.638      0.000       2.324       2.438
# ...

# %%
df_hv['emails_opnd'].mean()
# Out:
# 5.959555693165106

# %%
df_mv['emails_opnd'].mean()
# Out:
# 6.100448753906563

# %%
df_lv['emails_opnd'].mean()
# Out:
# 5.777016204134848

# %%
df_hv['calls_cmpltd'].mean()
# Out:
# 1.412028794798359

# %%
df_mv['calls_cmpltd'].mean()
# Out:
# 1.4546037342735796

# %%
df_lv['calls_cmpltd'].mean()
# Out:
# 1.3736263736263736

# %%
df_final['brnd_sls'].groupby(df_final['spec_grp']).describe()
# Out:
#                              count      mean        std  ...  50%   75%   max
# spec_grp                                                 ...
# ALLERGY/IMMUNO                41.0  6.073171  10.299006  ...  4.0  5.00  64.0
# ANESTHESIOLOGY                43.0  4.302326   2.395779  ...  4.0  5.50  11.0
# CARDIOLOGY                  6740.0  4.456380   2.118624  ...  4.0  6.00  33.0
# DERMATOLOGY                   17.0  4.823529   1.185079  ...  5.0  6.00   6.0
# EMERGENCY MEDICINE           296.0  4.648649   2.118089  ...  4.0  6.00  12.0
# ENDO/DIAB/META              2021.0  4.648689   2.291676  ...  4.0  6.00  30.0
# FAMILY/GEN. PRAC           30440.0  4.886827   2.863072  ...  5.0  6.00  70.0
# GERIATRICS                   637.0  4.670330   2.217275  ...  5.0  6.00  12.0
# INTERNAL MEDICINE          24641.0  4.852441   2.716140  ...  5.0  6.00  70.0
# MEDICAL GENETICS               2.0  3.000000   1.414214  ...  3.0  3.50   4.0
# ...

# %% [markdown]
# # Feature engineering

# %%
df_endcoded['CCR'] = df_endcoded['calls_cmpltd']/df_endcoded['atmptd_calls']
df_endcoded['EOR'] = df_endcoded['emails_opnd']/df_endcoded['emails_snt']

# %%
df_endcoded.fillna(0,inplace=True)

# %%
df_model_engg = df_endcoded.copy()

# %%
X = df_model_engg.drop({'brnd_sls','calls_cmpltd','atmptd_calls','emails_opnd','emails_snt'}, axis=1, inplace=False)
y = df_model_engg.pop('brnd_sls')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth' : [6,8,10,12],
    'min_samples_leaf' : [50,100,200,500],
    'min_samples_split' : [100,300,600,900],
    'max_features' : [3],
    'n_estimators' : [100,200,300],
    'random_state' : [1]
}

# %%
rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid,n_jobs=2, cv = 3, verbose=True)
rf_gs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 192 candidates, totalling 576 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=2)]: Done 576 out of 576 | elapsed: 25.6min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
# ...

# %%
best_rf = rf_gs.best_estimator_
ytrain_predict = best_rf.predict(X_train)
ytest_predict = best_rf.predict(X_test)

# %%
importances = pd.DataFrame(best_rf.feature_importances_, columns = ['Imp'], index = X_train.columns)
importances['features'] = pd.DataFrame(best_rf.feature_importances_, columns = ['Imp'], index = X_train.columns).index
importances.reset_index

importances = importances.sort_values(by='Imp', ascending=False)
importances.set_index(np.arange(0,importances.shape[0]),inplace = True)

importances['cumsum'] = np.cumsum(importances.Imp)
x_vals = list(range(len(importances)))

sns.barplot(data = importances, x='features', y='Imp')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Feature Importance');
plt.show()

plt.plot(x_vals, importances['cumsum'], 'g-')
plt.hlines(y = 0.95, xmin=0, xmax=len(importances), color = 'r', linestyles = 'dashed')
plt.xticks(x_vals, importances['features'], rotation='30')
plt.ylabel('Importance'); plt.xlabel('Features'); plt.title('Cumulative Importance');
plt.show()

# %%
importances
# Out:
#          Imp         features    cumsum
# 0   0.363231              EOR  0.363231
# 1   0.289480  tot_mkt_sls_new  0.652711
# 2   0.160229              CCR  0.812940
# 3   0.089004        faxes_snt  0.901944
# 4   0.078018   tot_brnded_sls  0.979962
# 5   0.012628            reg_2  0.992590
# 6   0.004747     tot_comp_sls  0.997336
# 7   0.001506            reg_1  0.998842
# 8   0.000738       spec_grp_2  0.999580
# 9   0.000420       spec_grp_1  1.000000
# 10  0.000000            reg_0  1.000000
# 11  0.000000       spec_grp_0  1.000000

# %%
import joblib
joblib.dump(best_rf, "./random_forest.joblib")
# Out:
# ['./random_forest.joblib']

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_train, ytrain_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_train, ytrain_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_train, ytrain_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_train, ytrain_predict))
print('Max Error:', metrics.max_error(y_train, ytrain_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_train, ytrain_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_train, ytrain_predict))
print('R^2:', metrics.r2_score(y_train, ytrain_predict))
# Out:
# Mean Absolute Error (MAE): 0.4877594695220433
# Mean Squared Error (MSE): 1.6109081371922174
# Root Mean Squared Error (RMSE): 1.2692155597817958
# Explained Variance Score: 0.7702267550660513
# Max Error: 53.44707495271527
# Mean Squared Log Error: 0.017766530019513643
# Median Absolute Error: 0.37632317091022127
# R^2: 0.7702266056385462

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, ytest_predict))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, ytest_predict))
print('Root Mean Squared Error (RMSE):', metrics.mean_squared_error(y_test, ytest_predict, squared=False))
print('Explained Variance Score:', metrics.explained_variance_score(y_test, ytest_predict))
print('Max Error:', metrics.max_error(y_test, ytest_predict))
print('Mean Squared Log Error:', metrics.mean_squared_log_error(y_test, ytest_predict))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, ytest_predict))
print('R^2:', metrics.r2_score(y_test, ytest_predict))
# Out:
# Mean Absolute Error (MAE): 0.5036398410144599
# Mean Squared Error (MSE): 1.8614028603019508
# Root Mean Squared Error (RMSE): 1.3643323862981303
# Explained Variance Score: 0.7496865551343987
# Max Error: 54.430206039033465
# Mean Squared Log Error: 0.018163115146653676
# Median Absolute Error: 0.3826828060485017
# R^2: 0.7496547871732289

# %%
sns.scatterplot(x=y_train,y=ytrain_predict); plt.xlabel('Training labels'); plt.ylabel('Predictions'); plt.show()

# %%
sns.scatterplot(x=y_test,y=ytest_predict); plt.xlabel('Test labels'); plt.ylabel('Predictions'); plt.show()
